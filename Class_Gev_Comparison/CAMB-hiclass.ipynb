# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d

# %% [markdown]
# # Stress tensor powerspectrum

# %%
delta_1=np.loadtxt("./lcdm_pk000_delta.dat")
delta_3=np.loadtxt("./lcdm_pk002_delta.dat")
deltaN_1=np.loadtxt("./lcdm_pk000_deltaN.dat")
deltaN_3=np.loadtxt("./lcdm_pk002_deltaN.dat")
pi_k_1=np.loadtxt("./lcdm_pk000_pi_k.dat")
pi_k_3=np.loadtxt("./lcdm_pk002_pi_k.dat")

# %%
plt.plot(delta_1[:,0],delta_1[:,1],color="Blue",label=r" z=3")
plt.plot(delta_3[:,0], delta_3[:,1],color="red",label=r"z=0")
plt.legend(bbox_to_anchor=(0., 1.01, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$P_{\delta}[Mpc^3]$")
plt.xlim(0.03,1-0.0001)
# plt.savefig('field_derivative_comparison.jpg',bbox_inches='tight')
plt.show()

# %%
plt.plot(delta_1[:,0],delta_1[:,1],color="Blue",label=r" z=3")
plt.plot(delta_3[:,0], delta_3[:,1],color="red",label=r"z=0")
plt.legend(bbox_to_anchor=(0., 1.01, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$P_{\delta}[Mpc^3]$")
plt.xlim(0.03,1-0.0001)
# plt.savefig('field_derivative_comparison.jpg',bbox_inches='tight')
plt.show()

# %%
plt.plot(pi_k_1[:,0],pi_k_1[:,1],color="Blue",label=r" z=3")
plt.plot(pi_k_3[:,0], pi_k_3[:,1],color="red",label=r"z=0")
plt.legend(bbox_to_anchor=(0., 1.01, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$P_{\pi}[Mpc^3]$")
plt.xlim(0.03,1-0.0001)
# plt.savefig('field_derivative_comparison.jpg',bbox_inches='tight')
plt.show()

# %%
plt.plot(pi_k_1[:,0],pi_k_1[:,1],color="Blue",label=r" z=3")
plt.plot(pi_k_3[:,0], pi_k_3[:,1],color="red",label=r"z=0")
plt.legend(bbox_to_anchor=(0., 1.01, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$P_{\pi}[Mpc^3]$")
# plt.xlim(0.03,1-0.0001)
# plt.savefig('field_derivative_comparison.jpg',bbox_inches='tight')
plt.show()

# %%
plt.plot(deltaN_1[:,0],deltaN_1[:,1],color="Blue",label=r" z=3")
plt.plot(deltaN_3[:,0], deltaN_3[:,1],color="red",label=r"z=0")
plt.legend(bbox_to_anchor=(0., 1.01, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$P_{\pi}[Mpc^3]$")
# plt.xlim(0.03,1-0.0001)
# plt.savefig('field_derivative_comparison.jpg',bbox_inches='tight')
plt.show()

# %%
plt.plot(pi_k_1[:,0],pi_k_1[:,1],color="Blue",label=r" z=3")
plt.plot(pi_k_3[:,0], pi_k_3[:,1],color="red",label=r"z=0")
plt.legend(bbox_to_anchor=(0., 1.01, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$P_{\pi}[Mpc^3]$")
# plt.xlim(0.03,1-0.0001)
# plt.savefig('field_derivative_comparison.jpg',bbox_inches='tight')
plt.show()

# %% [markdown]
# # Comparison between field transfer in hi-class and EFTcamb

# %%
Class=np.loadtxt("./kessence.dat")
Gev_piv=np.loadtxt("./lcdm_pk000_pi_k_v.dat")
Gev_pi=np.loadtxt("./lcdm_pk000_pi_k.dat")

# %%
As=2.19*10**-9;
h=0.67;
kp=0.05/h; 
ns=0.96;
P_class_dimensionless=As*(Class[:,2]**2)*((Class[:,0]/kp)**(ns-1.));

plt.plot(Gev_piv[:,0],Gev_piv[:,1],color="Blue",label=r"Gev")
plt.plot(Class[:,0], P_class_dimensionless[:],color="red",label=r"hi-class")
plt.legend(bbox_to_anchor=(0., 1.01, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$P_{\pi'}[Mpc^3]$")
plt.xlim(0.01,1-0.001)
# plt.savefig('field_derivative_comparison.jpg',bbox_inches='tight')
plt.show()

# %%
As=2.19*10**-9;
h=0.67;
kp=0.05/h; 
ns=0.96;
P_class_dimensionless=As*(Class[:,1]**2)*((Class[:,0]/kp)**(ns-1));
plt.plot(Gev_pi[:,0],Gev_pi[:,1],color="Blue",label=r"Gev")
plt.plot(Class[:,0], P_class_dimensionless[:],color="Magenta",label=r"hi-class, cs=1")
plt.legend(bbox_to_anchor=(0., 1.21, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$P$")
plt.xlim(0.01,1.)
# plt.savefig('field_derivative_comparison.jpg',bbox_inches='tight')
plt.show()

# %%
plt.plot(class_test_newt[:111,0],pi_class_cs0,color="Blue",label=r"class_pi_cs0")
plt.plot(class_test_newt[:111,0],pi_class_cs1,color="Black",label=r"class_pi_cs1")
plt.plot(hiclass_cs0[:,0]/h, pi_hiclass_cs0,color="red",label=r"hi-class, cs=0")
plt.plot(hiclass_cs1[:,0]/h, -pi_hiclass_cs1,color="Magenta",label=r"hi-class, cs=1")
plt.plot(Final_file_camb_cs0[:111,0],-pi_EFTcamb_cs0,color="Green",label=r"Eftcamb, cs0")
plt.plot(Final_file_camb_cs0[:111,0],-pi_EFTcamb_cs1,color="yellow",label="Eftcamb, cs1")
plt.legend(bbox_to_anchor=(0., 1.21, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('field_derivative_comparison.jpg',bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ea691ad74c88> in <module>()
# ----> 1 plt.plot(class_test_newt[:111,0],pi_class_cs0,color="Blue",label=r"class_pi_cs0")
#       2 plt.plot(class_test_newt[:111,0],pi_class_cs1,color="Black",label=r"class_pi_cs1")
#       3 plt.plot(hiclass_cs0[:,0]/h, pi_hiclass_cs0,color="red",label=r"hi-class, cs=0")
#       4 plt.plot(hiclass_cs1[:,0]/h, -pi_hiclass_cs1,color="Magenta",label=r"hi-class, cs=1")
#       5 plt.plot(Final_file_camb_cs0[:111,0],-pi_EFTcamb_cs0,color="Green",label=r"Eftcamb, cs0")
#
# NameError: name 'class_test_newt' is not defined

# %%
# plt.plot(class_test_newt[:111,0],pi_prime_class_cs0,color="Blue",label=r"class_pi'_cs0")
plt.plot(class_test_newt[:111,0],pi_prime_class_cs1,color="Black",label=r"class_pi'_cs1")
# plt.plot(hiclass_cs0[:,0]/h, pi_prime_hiclass_cs0,color="red",label=r"hi-class,pi' cs=0")
plt.plot(hiclass_cs1[:,0]/h, -pi_prime_hiclass_cs1,color="Magenta",label=r"hi-class,pi' cs=1")
# plt.plot(Final_file_camb_cs0[:111,0],pi_prime_EFTcamb_cs0,color="Green",label=r"Eftcamb,pi' cs0")
plt.plot(Final_file_camb_cs0[:111,0],pi_prime_EFTcamb_cs1,color="yellow",label="Eftcamb,pi' cs1")
plt.legend(bbox_to_anchor=(0., 1.21, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
# plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('field_derivative_comparison.jpg',bbox_inches='tight')
plt.show()

# %%
psi=hiclass_cs0[:,4]
deltaclass=class_test_newt[:,4]
pi_primeclass=10**-4*(deltaclass[:111])+psi[:111]
pi_primeEFTcamb=Final_file_camb_cs0[:,2]
pi_hiclass= hiclass_cs0[:,3]
h=0.67
As=2.215*10.e-9
ns=0.96
kp=0.05
deltaR2=2*np.pi**2*As*(hiclass_cs0[:,0]/kp)**(ns-1)/((hiclass_cs0[:,0])**(3))
Hubb=2.25e-4;
plt.plot(hiclass_cs0[:,0]/h,pi_primeclass[:]*np.sqrt(deltaR2[:111]),color="Blue",label=r"class")
plt.plot(Final_file_camb_cs0[:,0]/h, pi_primeEFTcamb[:]*Hubb,color="Black",label=r"EFTcamb")
plt.plot(hiclass_cs0[:,0], -pi_hiclass[:]*np.sqrt(deltaR2[:]),color="red",label=r"hi-class")
# plt.plot(Final_file_camb_cs1[:,0]/h, -Final_file_camb_cs1[:,1],color="Green",label=r"CAMB,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")
# plt.plot(class_test_newt[:,0],-class_test_newt[:,3],color="Green",label=r"Newt DM")
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.11, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
plt.savefig('field_derivative_comparison.jpg',bbox_inches='tight')
plt.show()

# %%
delta_new_camb_cs0=1.e4*(- hiclass_cs0[:111,4]+Final_file_camb_cs0[:111,2])
delta_new_hi_cs0=hiclass_cs0[:,1];
delta_new_class_cs0=-class_Newt[:,4]
delta_new_class_cdm=-class_Newt[:,3]

# %%
plt.plot(hiclass_cs0[:,0],hiclass_cs0[:,4],color="Blue",label=r"P_R, same model and parameters")
# plt.plot(class_Newt[:,0], delta_new_class_cs0[:],color="Black",label=r"hi-class,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")
# plt.plot(class_Newt[:,0], delta_new_class_cdm[:],color="magenta",label=r"CAMB,$c_s^2=10^{-8}, w_0=-1$ , z=0")
# plt.plot(Final_file_camb_cs1[:,0]/h, -Final_file_camb_cs1[:,1],color="Green",label=r"CAMB,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")


# plt.plot(class_test_newt[:,0],-class_test_newt[:,3],color="Green",label=r"Newt DM")

# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.21, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
h=0.67
As=2.215*10.e-9
ns=0.96
kp=0.05
deltaR2=2*np.pi**2*As*(hiclass_cs0[:,0]/kp)**(ns-1)/((hiclass_cs0[:,0])/h**(3))
Hubb=2.25e-4;
# plt.plot([1.e-4/h,1.e-2/h,0.1/h], [3.43e-6, 0.02210,0.2283], "*",color="Black",label=r"hi-class direct output using k_output_values")
# alpha=(-class_synch[:111,4]+class_Newt[:111,4])
# deltarho_Synchc1=deltarho_newtc1-3e-4*Hubb*alpha
# deltarho_newtc0=hiclass_cs0[:,5]
# deltarho_Synchc0=deltarho_newtc1-3.e-4*Hubb*alpha
# plt.plot(hiclass_cs0[:,0]/h, hiclass_cs0[:,2]*np.sqrt(deltaR2),color="red",label=r"hi-class using perturbation.c")
# plt.plot(Final_file_camb_cs1[:111,0]/h, -Final_file_camb_cs1[:111,1]*Hubb,color="Blue",label=r"EFTcamb, same model and parameters")
plt.plot(hiclass_cs0[:,0]/h, hiclass_cs0[:,2]*(np.sqrt(deltaR2)),color="red",label=r"hi-class using perturbation.c")
plt.plot(Final_file_camb_cs1[:111,0], -Final_file_camb_cs1[:111,1]*Hubb,color="Blue",label=r"EFTcamb, same model and parameters")

# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.05, 1., .102), loc=1,ncol=1,fontsize=8, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('test_2.jpg',bbox_inches='tight')
plt.show()

# %%
h=0.67
# Hubb=2.25e-4;
# alpha=(-class_synch[:111,4]+class_Newt[:111,4])
# deltarho_Synchc1=deltarho_newtc1-3e-4*Hubb*alpha
# deltarho_newtc0=hiclass_cs0[:,5]
# deltarho_Synchc0=deltarho_newtc1-3.e-4*Hubb*alpha
plt.plot(Final_file_camb_cs0[:111,0]/h, -delta_new_camb_cs0[:],color="red",label=r"CAMB,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")
plt.plot(hiclass_cs0[:,0]/h, delta_new_hi_cs0,color="Blue",label=r"hi-class,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")
plt.plot(class_Newt[:,0], delta_new_class_cs0[:],color="Black",label=r"hi-class,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")
plt.plot(class_Newt[:,0], delta_new_class_cdm[:],color="magenta",label=r"CAMB,$c_s^2=10^{-8}, w_0=-1$ , z=0")
# plt.plot(Final_file_camb_cs1[:,0]/h, -Final_file_camb_cs1[:,1],color="Green",label=r"CAMB,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")


# plt.plot(class_test_newt[:,0],-class_test_newt[:,3],color="Green",label=r"Newt DM")

# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.41, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
h=0.67
Hubb=2.25e-4;
# alpha=(-class_synch[:111,4]+class_Newt[:111,4])
# deltarho_Synchc1=deltarho_newtc1-3e-4*Hubb*alpha
# deltarho_newtc0=hiclass_cs0[:,5]
# deltarho_Synchc0=deltarho_newtc1-3.e-4*Hubb*alpha
plt.plot(hiclass_cs0[:,0]/h, hiclass_cs0[:,2]*np.sqrt(deltaR2),color="Black",label=r"hi-class,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")
# plt.plot(hiclass_cs0[:,0]/h, -hiclass_cs0[:,2],color="Blue",label=r"hi-class,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")
# plt.plot(hiclass_cs0[:,0]/h, -hiclass_cs1[:,2],color="Black",label=r"hi-class,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")
plt.plot(Final_file_camb_cs0[:,0], -Final_file_camb_cs0[:,1]*Hubb,color="magenta",label=r"CAMB,$c_s^2=10^{-8}, w_0=-1$ , z=0")
# plt.plot(Final_file_camb_cs1[:,0]/h, -Final_file_camb_cs1[:,1],color="Green",label=r"CAMB,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")


# plt.plot(class_test_newt[:,0],-class_test_newt[:,3],color="Green",label=r"Newt DM")

# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.41, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
# plt.xscale('log')
# plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
h=0.67
Hubb=2.25e-4;
alpha=(-class_synch[:111,4]+class_Newt[:111,4])
# deltarho_Synchc1=deltarho_newtc1-3e-4*Hubb*alpha
deltarho_newtc0=hiclass_cs0[:,5]
deltarho_Synchc0=deltarho_newtc1-3.e-4*Hubb*alpha
plt.plot(hiclass_cs0[:,0]/h, -hiclass_cs0[:,5],color="red",label=r"hi-class,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")
plt.plot(hiclass_cs0[:,0]/h, -deltarho_Synchc0[:],color="Magenta",label=r"hi-class,Synch,$c_s^2=10^{-8}, w_0=-1$ , z=0")
plt.plot(class_test_newt[:,0],-class_test_newt[:,4],color="Blue",label=r"Newt, fluid")
plt.plot(class_synch[:,0],class_synch[:,4],color="Yellow",label=r"Synch, fluid")
# plt.plot(class_test_newt[:,0],-class_test_newt[:,3],color="Green",label=r"Newt DM")

# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.41, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-96320f6bbef3> in <module>()
#       4 # deltarho_Synchc1=deltarho_newtc1-3e-4*Hubb*alpha
#       5 deltarho_newtc0=hiclass_cs0[:,5]
# ----> 6 deltarho_Synchc0=deltarho_newtc1-3.e-4*Hubb*alpha
#       7 plt.plot(hiclass_cs0[:,0]/h, -hiclass_cs0[:,5],color="red",label=r"hi-class,Newt,$c_s^2=10^{-8}, w_0=-1$ , z=0")
#       8 plt.plot(hiclass_cs0[:,0]/h, -deltarho_Synchc0[:],color="Magenta",label=r"hi-class,Synch,$c_s^2=10^{-8}, w_0=-1$ , z=0")
#
# NameError: name 'deltarho_newtc1' is not defined

# %%
# Out:
# 9.869604401089358

# %% [markdown]
#   # Plots: Density transfer function in the limits c_s=e-4 , w0=-0.9999

# %%
h=0.67
Hubb=2.25e-4;
deltarho_newtc1=hiclass_cs1[:,2]
alpha=(-class_synch[:111,4]+class_Newt[:111,4])
deltarho_Synchc1=deltarho_newtc1-3e-4*Hubb*alpha;
deltaR2=2*np.pi**2*As*(hiclass_cs0[:,0]/kp)**(ns-1)/((hiclass_cs0[:,0]/h)**(3./2.))
# plt.plot(class_test_synch[:,0],-class_test_synch[:,4],color="black",label=r"class,$c_s^2=10^{-8}, w_0=-0.9999$ Synch field, z=0")
# plt.plot(class_test_synch[:,0],-class_test_synch[:,3],color="red",label=r"Class,$c_s^2=10^{-8}, w_0=-0.9999$ synch DM ")
# plt.plot(class_test_newt[:,0],-class_test_newt[:,4],color="Blue",label=r"Class, Newt,$c_s^2=10^{-8}, w_0=-0.9999$  field")
# plt.plot(class_test_newt[:,0],-class_test_newt[:,3],color="Green",label=r"Class, Newt,$c_s^2=10^{-8}, w_0=-0.9999$ DM")
# plt.plot(class_Newt[:,0],-class_Newt[:,3],color="Blue",label=r"Class, Newt $c_s^2=1,cs=0,w_0=-0.9999, z=0$")
plt.plot(hiclass_cs0[:,0]/h,-deltarho_newt[:],color="khaki",label="hi-class cs=0,w_0=-0.9999, z=0")
plt.plot(hiclass_cs0[:,0]/h,-deltarho_Synch[:],color="green",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs1[:,0]/h,-deltarho_Synchc1[:],color="Magenta",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs0[:,0]/h,-hiclass_cs0[:,2],color="blue",label=r"hi-class,Newt, $\delta_{\pi}, cs=10^{-4},w_0=-0.9999, z=0$")
# plt.plot(hiclass_cs1[:,0]/h,-hiclass_cs1[:,2],color="black",label=r"hi-class,Newt, $\delta_{\pi}, cs=1,w_0=-0.9, z=0$")
# plt.plot(hiclass_cs0[:,0]/h,-hiclass_cs0[:,2]+3.e-4*Hubb*hiclass_cs0[:,3],color="green",label=r"hi-class, Synch, $\delta_{\pi}, cs=10^{-4},w_0=-0.9999, z=0$")
# plt.plot(hiclass_cs1[:,0]/h,-hiclass_cs1[:,2]+0.3*Hubb*hiclass_cs1[:,3],color="magenta",label=r"hi-class, Synch, $\delta_{\pi}, cs=1,w_0=-0.9, z=0$")
plt.plot(Final_file_camb_cs0[:111,0],-Final_file_camb_cs0[:111,1]*Hubb/np.sqrt(deltaR2),color="magenta",label="EFTcamb,$c_s^2=10^{-8}, w_0=-0.9999$, z=0")

# plt.plot(Final_file_camb_cs0[:,0],-Final_file_camb_cs0[:,1],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(cdm_hiclass[:,0],-cdm_hiclass[:,3],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(Final_file_camb_cs1[:,0],-Final_file_camb_cs1[:,1]/Final_file_camb_cs1[:,0],color="Magenta",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(class_synch[:,0],class_synch[:,3],color="Green",label="Class, ,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classSynz100[:,0],file_classSynz100[:,4],color="Blue",label="Class_Sync_z=100, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(Myfield[:,0],Myfield[:,3]/(3.1415*(Myfield[:,0]/(0.05))**(0.96-1)),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")

# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.51, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %% [markdown]
# # alpha comparison

# %%
plt.plot(class_synch[:,0],-(-class_synch[:,4]+class_Newt[:,4])/(0.3*Hubb),color="red",label=r"class, alpha from T_newt-T_synch/coeff , z=0")
# plt.plot(class_Newt[:,0],-class_Newt[:,3],color="green",label=r"Class, Newt $c_s^2=1,cs=0,w_0=-0.9999, z=0$")
# plt.plot(hiclass_cs0[:,0]/h,-deltarho_newt[:],color="black",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs0[:,0]/h,-deltarho_Synch[:],color="Blue",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs1[:,0]/h,-deltarho_Synchc1[:],color="Magenta",label="hi-class cs=0,w_0=-0.9999, z=0")

plt.plot(hiclass_cs1[:,0]/h,hiclass_cs1[:,3],color="blue",label="hi-class,alpha cs=1,w_0=-0.9, z=0")
# plt.plot(class_Newt[:,0]/h,class_Newt[:,3],color="green",label="hi-class cs=1,w_0=-0.9, z=0")

# plt.plot(Final_file_camb_cs0[:,0],-Final_file_camb_cs0[:,1],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(cdm_hiclass[:,0],-cdm_hiclass[:,3],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(Final_file_camb_cs1[:,0],-Final_file_camb_cs1[:,1]/Final_file_camb_cs1[:,0],color="Magenta",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(class_synch[:,0],class_synch[:,3],color="Green",label="Class, ,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classSynz100[:,0],file_classSynz100[:,4],color="Blue",label="Class_Sync_z=100, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(Myfield[:,0],Myfield[:,3]/(3.1415*(Myfield[:,0]/(0.05))**(0.96-1)),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")

# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.11, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8a810dd34afc> in <module>()
# ----> 1 plt.plot(class_synch[:,0],-(-class_synch[:,4]+class_Newt[:,4])/(0.3*Hubb),color="red",label=r"class, alpha from T_newt-T_synch/coeff , z=0")
#       2 # plt.plot(class_Newt[:,0],-class_Newt[:,3],color="green",label=r"Class, Newt $c_s^2=1,cs=0,w_0=-0.9999, z=0$")
#       3 # plt.plot(hiclass_cs0[:,0]/h,-deltarho_newt[:],color="black",label="hi-class cs=0,w_0=-0.9999, z=0")
#       4 # plt.plot(hiclass_cs0[:,0]/h,-deltarho_Synch[:],color="Blue",label="hi-class cs=0,w_0=-0.9999, z=0")
#       5 # plt.plot(hiclass_cs1[:,0]/h,-deltarho_Synchc1[:],color="Magenta",label="hi-class cs=0,w_0=-0.9999, z=0")
#
# NameError: name 'plt' is not defined

# %%
# plt.plot(class_synch[:,0],class_synch[:,4],color="red",label=r"class, alpha from T_newt-T_synch/coeff , z=0")
plt.plot(class_synch[:,0],class_synch[:,4]*10**-2.03,color="red",label=r"Class, Newt $c_s^2=1,cs=0,w_0=-0.9999, z=0$")
# plt.plot(hiclass_cs0[:,0]/h,-deltarho_newt[:],color="black",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs0[:,0]/h,-deltarho_Synch[:],color="Blue",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs1[:,0]/h,-deltarho_Synchc1[:],color="Magenta",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs1[:,0]/h,-hiclass_cs1[:,2],color="blue",label="hi-class,alpha cs=1,w_0=-0.9, z=0")
# plt.plot(hiclass_cs1[:,0]/h,hiclass_cs1[:,3],color="magenta",label="hi-class,alpha cs=1,w_0=-0.9, z=0")
# plt.plot(hiclass_cs1[:,0]/h,hiclass_cs1[:,1],color="black",label="hi-class,alpha cs=1,w_0=-0.9, z=0")
# plt.plot(Final_file_camb_cs0[:,0],-Final_file_camb_cs0[:,1],color="red",label="EFTcamb,$c_s^2=10^{-8}, w_0=-0.9999$, z=0")

# plt.plot(class_Newt[:,0]/h,class_Newt[:,3],color="green",label="hi-class cs=1,w_0=-0.9, z=0")

plt.plot(Final_file_camb_cs0[:,0],-Final_file_camb_cs0[:,1]*Hubb,color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(cdm_hiclass[:,0],-cdm_hiclass[:,3],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(Final_file_camb_cs1[:,0],-Final_file_camb_cs1[:,1]/Final_file_camb_cs1[:,0],color="Magenta",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(class_synch[:,0],class_synch[:,3],color="Green",label="Class, ,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classSynz100[:,0],file_classSynz100[:,4],color="Blue",label="Class_Sync_z=100, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(Myfield[:,0],Myfield[:,3]/(3.1415*(Myfield[:,0]/(0.05))**(0.96-1)),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")

# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.41, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()
