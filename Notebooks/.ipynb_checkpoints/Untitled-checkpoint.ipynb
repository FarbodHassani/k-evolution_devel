# %%
import sys
import csv
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %%
import random

a= [1,2,3,4,5]
random.choices(a,k=3)
# Out:
# [2, 3, 3]

# %%
import numpy as np
import time,sys,os
import readsnap,readgadget
import redshift_space_library as RSL
import MAS_library as MASL

# %%
snapshot = './../../KGBevolution/output/lcdm_snap000_cdm'

# %%
import readgadget
a = readsnap.read_block(snapshot,"POS ", 1)
a = a[:10000,:]
nums = np.shape(a)[0]
# rnd = np.transpose([random.choices(a[:,0],k=nums),random.choices(a[:,1],k=nums),random.choices(a[:,2],k=nums)])

# %%
rnd = random.choices(a,k=20)
rnd = np.array(rnd)
# rnd = np.transpose([np.unique(rnd[:,0]),np.unique(rnd[:,1]),np.unique(rnd[:,2])])

# %%
np.unique(rnd[:,0])
# Out:
# array([ 10135.762,  30108.24 ,  50023.39 ,  70005.96 ,  89889.95 ,
#         89975.85 , 109974.086, 129649.29 , 150274.06 , 170080.89 ,
#        190066.69 , 209783.81 , 209996.61 , 209999.86 , 210331.2  ,
#        229918.6  , 249950.66 , 269819.   , 289680.1  , 310002.6  ],
#       dtype=float32)

# %%
# rnd[:,0] == np.unique(rnd[:,0])

# %%
np.unique(rnd[:,0]).shape
# Out:
# (20,)

# %%
rnd.shape
# Out:
# (20, 3)

# %%
# rnd[:,0].sum()

# %%
a[:,0].sum()
# Out:
# 1000099.6

# %%
a
# Out:
# array([[  9592.61 ,   9848.086,   9623.756],
#        [ 29699.328,   9888.805,   9630.681],
#        [ 49769.074,   9878.162,   9541.692],
#        [ 69838.9  ,   9933.575,   9461.711],
#        [ 89939.4  ,  10078.538,   9424.899],
#        [110052.46 ,  10198.161,   9377.706],
#        [130273.78 ,  10235.485,   9355.212],
#        [150388.48 ,  10205.702,   9347.739],
#        [170263.5  ,  10136.793,   9324.341],
#        [190282.16 ,  10076.96 ,   9397.687]], dtype=float32)

# %%
rnd
# Out:
# array([[  9592.61 ,   9848.086,   9324.341],
#        [ 49769.074,   9878.162,   9347.739],
#        [ 69838.9  ,   9933.575,   9355.212],
#        [ 89939.4  ,  10076.96 ,   9377.706],
#        [110052.46 ,  10078.538,   9397.687],
#        [130273.78 ,  10136.793,   9424.899],
#        [150388.48 ,  10198.161,   9461.711],
#        [170263.5  ,  10205.702,   9541.692],
#        [190282.16 ,  10235.485,   9623.756]], dtype=float32)

# %%
from matplotlib.pyplot import figure


X, Y, Z = rnd[:,0],  rnd[:,1],  rnd[:,2]
X1, Y1, Z1 = a[:,0],  a[:,1],  a[:,2]
# Plot X,Y,Z
fig = plt.figure(figsize=(12, 12), dpi=80)
ax = fig.add_subplot(111, projection='3d')
# ax.plot_trisurf(X, Y, Z, color='white', edgecolors='grey', alpha=0.5)
ax.scatter(X, Y, Z, c='red',s=90)
ax.scatter(X1, Y1, Z1, c='blue',s=10)
plt.show()

# %%
X.shape
# Out:
# (4096,)

# %%
X1.shape
# Out:
# (4096,)
