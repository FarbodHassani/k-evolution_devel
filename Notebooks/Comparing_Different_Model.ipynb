# %%
import numpy as np
import matplotlib.pylab 
# from __future__ import unicode_literals
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['text.latex.unicode'] = True
from scipy.misc import toimage
# from matplotlib.patches import Rectangle
from decimal import *
import math
import matplotlib.pyplot as plt
from numpy import matrix
# %matplotlib inline

# %%
pi_k=np.loadtxt("./output/lcdm_pk000_pi_k.dat")
pi_k_v=np.loadtxt ("./output/lcdm_pk000_pi_k_v.dat")
phi=np.loadtxt("./output/lcdm_pk000_phi.dat")

# %%
pi_k_v[:,0];

# %%
plt.plot (pi_k[:,0],pi_k[:,1],"r")
plt.plot (pi_k_v[:,0],pi_k_v[:,1],"b")
plt.plot (phi[:,0],phi[:,1],"magenta")

# %%
sec_approx=np.loadtxt("2nd_approx_info.txt")
sec_exact=np.loadtxt("2nd_exact_info.txt")
euler_half=np.loadtxt("euler_half_info.txt")
euler=np.loadtxt("euler_info.txt")
exact=np.loadtxt("Per_info_exact.txt")
gr=np.loadtxt("GR.txt")
gr[:7]
gr[7:10]
gr[7:10].shape, gr[0:7].shape
x[0:7]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-56-37797335d9b6> in <module>()
#       1
# ----> 2 sec_approx=np.loadtxt("2nd_approx_info.txt")
#       3 sec_exact=np.loadtxt("2nd_exact_info.txt")
#       4 euler_half=np.loadtxt("euler_half_info.txt")
#       5 euler=np.loadtxt("euler_info.txt")
#
# /home/farbod/packages/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     801                 fh = iter(bz2.BZ2File(fname))
#     802             elif sys.version_info[0] == 2:
# --> 803                 fh = iter(open(fname, 'U'))
#     804             else:
#     805                 fh = iter(open(fname))
#
# IOError: [Errno 2] No such file or directory: '2nd_approx_info.txt'

# %%
# plt.plot(x[0:7],gr[0:7],marker='_',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
plt.plot(x[0:7],gr[0:7],label='GR-expected')
# plt(x[0:7],gr[0:7],label='GR-expected',marker='_')
plt.errorbar(x[0:7],sec_approx[0:7,0],sec_approx[0:7,1],marker='.',markersize='10',fmt='o' , color='Red',label='2nd order geodesic_method 1')
plt.errorbar(x[0:7],sec_exact[0:7,0],sec_exact[0:7,1],marker='.',markersize='10',fmt='o', color='Black', label='2nd order geodesic_method 2')
plt.errorbar(x[0:7],euler[0:7,0],euler[0:7,1],marker='.',markersize='10',fmt='o', color='Magenta',label='Gevolution solver-Euler normal method')
plt.errorbar(x[0:7],euler_half[0:7,0],euler_half[0:7,1],marker='.',markersize='10',fmt='o', color='orange',label='Gevolution solver-Euler half update method')
plt.errorbar(x[0:7],exact[0:7,0],exact[0:7,1],marker='.',markersize='10',fmt='o', color='green',label='First order geodesic')

plt.legend()
plt.xlabel(r"$\alpha$",fontsize=14)
plt.ylabel("Perihelion advance (Arcsec/415 orbits)",fontsize=14)
plt.yscale('log')
plt.xscale('log')
plt.legend(loc='upper right', bbox_to_anchor=(1.0, 0.35),fontsize=8)
plt.xlim(0.8*10**-3, 10**3)
# plt.ylim(10**-7, 10**14)
plt.savefig('all-1.jpg',bbox_inches='tight',dpi = 400)
plt.show()

# %%
# plt.errorbar(x[7:10],gr[7:10],marker='.',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
# plt.errorbar(x[7:10],approx[7:10,0],approx[7:10,1],marker='.',markersize='10',fmt='o' , color='Red',label='Approximated potentials')
# plt.errorbar(x[7:10],exact[7:10,0],exact[7:10,1],marker='.',markersize='10',fmt='o', color='Black', label='Exact potentials')
# plt.errorbar(x[7:10],param[7:10,0],param[7:10,1],marker='.',markersize='10',fmt='o', color='Magenta',label='Potentials in new parameterization')
# plt.legend()
# plt.xlabel(r"$\alpha$",fontsize=14)
# plt.ylabel("Perihelion advance (Arcsec/415 orbits)",fontsize=14) 
# plt.xscale('log')
# # plt.yscale('log')
# plt.legend(loc='upper right', bbox_to_anchor=(0.5, 1),fontsize=8)
# # plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# # plt.ylim()
# # plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
# #             size='7')
# plt.xlim(10**2, 10**7)
# plt.savefig('per_4to7_all_compare.jpg',bbox_inches='tight',dpi = 600)
# plt.show()
# plt.plot(x[0:7],gr[0:7],marker='_',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
plt.plot(x[7:9],gr[7:9],label='GR-expected')
# plt(x[0:7],gr[0:7],label='GR-expected',marker='_')
plt.errorbar(x[7:9],sec_approx[7:9,0],sec_approx[7:9,1],marker='.',markersize='10',fmt='o' , color='Red',label='2nd order geodesic_method 1')
plt.errorbar(x[7:9],sec_exact[7:9,0],sec_exact[7:9,1],marker='.',markersize='10',fmt='o', color='Black', label='2nd order geodesic_method 2')
plt.errorbar(x[7:9],euler[7:9,0],euler[7:9,1],marker='.',markersize='10',fmt='o', color='Magenta',label='Gevolution solver-Euler normal method')
plt.errorbar(x[7:9],euler_half[7:9,0],euler_half[7:9,1],marker='.',markersize='10',fmt='o', color='orange',label='Gevolution solver-Euler half update method')
plt.errorbar(x[7:9],exact[7:9,0],exact[7:9,1],marker='.',markersize='10',fmt='o', color='green',label='First order geodesic')

plt.legend()
plt.xlabel(r"$\alpha$",fontsize=14)
plt.ylabel("Perihelion advance (Arcsec/415 orbits)",fontsize=14)
# plt.yscale('log')
plt.xscale('log')
plt.legend(loc='upper right', bbox_to_anchor=(0.63, 1),fontsize=8)
plt.xlim(0.8*10**4, 1.2*10**5)
# plt.ylim(10**-7, 10**14)
plt.savefig('all-2.jpg',bbox_inches='tight',dpi = 400)
plt.show()

# %%
# plt.errorbar(x[0:7],((gr[0:7]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
plt.plot(x[0:7],((gr[0:7]-gr[0:7])/gr[0:7]),label='GR-expected')
plt.errorbar(x[0:7],((sec_approx[0:7,0]-gr[0:7])/gr[0:7]),sec_approx[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o' , color='Red',label='2nd order geodesic_method 1')
plt.errorbar(x[0:7],((sec_exact[0:7,0]-gr[0:7])/gr[0:7]),sec_exact[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='Black', label='2nd order geodesic_method 2')
plt.errorbar(x[0:7],((euler[0:7,0]-gr[0:7])/gr[0:7]),euler[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='Magenta',label='Gevolution solver-Euler normal method')
plt.errorbar(x[0:7],((euler_half[0:7,0]-gr[0:7])/gr[0:7]),euler_half[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='orange',label='Gevolution solver-Euler half update method')
plt.errorbar(x[0:7],((exact[0:7,0]-gr[0:7])/gr[0:7]),exact[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='green',label='First order geodesic')# plt.errorbar(x[0:7],((approx[0:7,0]-gr[0:7])/gr[0:7]),approx[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o' , color='Red',label='Approximated potentials')
# plt.errorbar(x[0:7],((exact[0:7,0]-gr[0:7])/gr[0:7]),exact[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='Black', label='Exact potentials')
# plt.errorbar(x[0:7],((param[0:7,0]-gr[0:7])/gr[0:7]),param[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='Magenta',label='Potentials in new parameterization')
# plt.errorbar(x[0:7],((gr[0:7]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
# plt.errorbar(x[0:7],((approx[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' , color='Red',label='Approximated potentials')
# plt.errorbar(x[0:7],((exact[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o', color='Black', label='Exact potentials')
# plt.errorbar(x[0:7],((param[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o', color='Magenta',label='Potentials in new parameterization')

# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')
# plt.legend()
plt.xlim(0.7*10**-2,10**5)
# plt.ylim(-0.5,0.5)
# plt.ylim()
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$\alpha$",fontsize=16)
plt.ylabel(r"$\frac{\theta_{Theory}-\theta_{GR}}{\theta_{GR}}$",fontsize=16)
plt.xscale('log')
# plt.yscale('log')
plt.legend(loc='upper right', bbox_to_anchor=(1, 1),fontsize=6)
# plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
# plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
#             size='7')
plt.ylim(-0.35, 0.3)
plt.savefig('relative_error_all_-3to4.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
# plt.errorbar(x[0:7],((gr[0:7]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
plt.plot(x[0:9],((gr[0:9]-gr[0:9])/gr[0:9]),label='GR-expected')
plt.errorbar(x[0:9],((sec_approx[0:9,0]-gr[0:9])/gr[0:9]),sec_approx[0:9,1]/gr[0:9],marker='.',markersize='10',fmt='o' , color='Red',label='2nd order geodesic_method 1')
plt.errorbar(x[0:9],((sec_exact[0:9,0]-gr[0:9])/gr[0:9]),sec_exact[0:9,1]/gr[0:9],marker='.',markersize='10',fmt='o', color='Black', label='2nd order geodesic_method 2')
plt.errorbar(x[0:9],((euler[0:9,0]-gr[0:9])/gr[0:9]),euler[0:9,1]/gr[0:9],marker='.',markersize='10',fmt='o', color='Magenta',label='Gevolution solver-Euler normal method')
plt.errorbar(x[0:9],((euler_half[0:9,0]-gr[0:9])/gr[0:9]),euler_half[0:9,1]/gr[0:9],marker='.',markersize='10',fmt='o', color='orange',label='Gevolution solver-Euler half update method')
plt.errorbar(x[0:9],((exact[0:9,0]-gr[0:9])/gr[0:9]),exact[0:9,1]/gr[0:9],marker='.',markersize='10',fmt='o', color='green',label='First order geodesic')# plt.errorbar(x[0:7],((approx[0:7,0]-gr[0:7])/gr[0:7]),approx[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o' , color='Red',label='Approximated potentials')
# plt.errorbar(x[0:7],((exact[0:7,0]-gr[0:7])/gr[0:7]),exact[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='Black', label='Exact potentials')
# plt.errorbar(x[0:7],((param[0:7,0]-gr[0:7])/gr[0:7]),param[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='Magenta',label='Potentials in new parameterization')
# plt.errorbar(x[0:7],((gr[0:7]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
# plt.errorbar(x[0:7],((approx[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' , color='Red',label='Approximated potentials')
# plt.errorbar(x[0:7],((exact[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o', color='Black', label='Exact potentials')
# plt.errorbar(x[0:7],((param[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o', color='Magenta',label='Potentials in new parameterization')

# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')
# plt.legend()
plt.xlim(0.8*10**-3,1.2*10**5)
plt.ylim(-1.6,0.5)
# plt.ylim()
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$\alpha$",fontsize=16)
plt.ylabel(r"$\frac{\theta_{Theory}-\theta_{GR}}{\theta_{GR}}$",fontsize=16)
plt.xscale('log')
# plt.yscale('log')
plt.legend(loc='upper right', bbox_to_anchor=(0.7, 0.3),fontsize=6)
# plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
# plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
#             size='7')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('relative_error_all_comp.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
# plt.errorbar(x[0:7],((gr[0:7]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
# plt.plot(x[0:9],((gr[0:9]-gr[0:9])),label='GR-expected')
# plt.errorbar(x[0:9],((sec_approx[0:9,0]-gr[0:9])/gr[0:9]),sec_approx[0:9,1]/gr[0:9],marker='.',markersize='10',fmt='o' , color='Red',label='2nd order geodesic_method 1')
plt.errorbar(x[0:9],(np.fabs(sec_exact[0:9,0]-gr[0:9])),sec_exact[0:9,1],marker='.',markersize='10',fmt='o', color='Black', label='2nd order geodesic_method 2')
plt.errorbar(x[0:9],(np.fabs(euler[0:9,0]-gr[0:9])),euler[0:9,1],marker='.',markersize='10',fmt='o', color='Magenta',label='Gevolution solver-Euler normal method')
plt.errorbar(x[0:9],(np.fabs(euler_half[0:9,0]-gr[0:9])),euler_half[0:9,1],marker='.',markersize='10',fmt='o', color='orange',label='Gevolution solver-Euler half update method')
plt.errorbar(x[0:9],(np.fabs(exact[0:9,0]-gr[0:9])),exact[0:9,1],marker='.',markersize='10',fmt='o', color='green',label='First order geodesic')# plt.errorbar(x[0:7],((approx[0:7,0]-gr[0:7])/gr[0:7]),approx[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o' , color='Red',label='Approximated potentials')
# plt.errorbar(x[0:7],((exact[0:7,0]-gr[0:7])/gr[0:7]),exact[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='Black', label='Exact potentials')
# plt.errorbar(x[0:7],((param[0:7,0]-gr[0:7])/gr[0:7]),param[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='Magenta',label='Potentials in new parameterization')
# plt.errorbar(x[0:7],((gr[0:7]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
# plt.errorbar(x[0:7],((approx[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' , color='Red',label='Approximated potentials')
# plt.errorbar(x[0:7],((exact[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o', color='Black', label='Exact potentials')
# plt.errorbar(x[0:7],((param[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o', color='Magenta',label='Potentials in new parameterization')

# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')
# plt.legend()
plt.xlim(0.8*10**-3,1.2*10**5)
plt.ylim(0.8*10**-3,10**9)
# plt.ylim()
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$\alpha$",fontsize=16)
plt.ylabel(r"$|\theta_{Theory}-\theta_{GR}|$",fontsize=16)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper right', bbox_to_anchor=(0.50, 1),fontsize=6)
# plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
# plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
#             size='7')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('Relative2.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
# plt.errorbar(x[0:7],((gr[0:7]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
# plt.plot(x[0:9],((gr[0:9]-gr[0:9])/gr[0:9]),label='GR-expected')
# plt.errorbar(x[0:9],((sec_approx[0:9,0]-gr[0:9])/gr[0:9]),sec_approx[0:9,1]/gr[0:9],marker='.',markersize='10',fmt='o' , color='Red',label='2nd order geodesic_method 1')
# plt.errorbar(x[0:9],((sec_exact[0:9,0]-sec_exact[0:9,0])/sec_exact[0:9,0]),sec_exact[0:9,1]/sec_exact[0:9,1],marker='.',markersize='10',fmt='o', color='Black', label='2nd order geodesic_method 2')
plt.errorbar(x[0:9],((euler[0:9,0]-sec_exact[0:9,0])/sec_exact[0:9,0]),euler[0:9,1]/sec_exact[0:9,0],marker='.',markersize='10',fmt='o', color='Magenta',label='Gevolution solver-Euler normal method')
plt.errorbar(x[0:9],((euler_half[0:9,0]-sec_exact[0:9,0])/sec_exact[0:9,0]),euler_half[0:9,1]/sec_exact[0:9,0],marker='.',markersize='10',fmt='o', color='orange',label='Gevolution solver-Euler half update method')
plt.errorbar(x[0:9],((exact[0:9,0]-sec_exact[0:9,0])/sec_exact[0:9,0]),sec_exact[0:9,1]/sec_exact[0:9,0],marker='.',markersize='10',fmt='o', color='green',label='First order geodesic')# plt.errorbar(x[0:7],((approx[0:7,0]-gr[0:7])/gr[0:7]),approx[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o' , color='Red',label='Approximated potentials')
# plt.errorbar(x[0:7],((exact[0:7,0]-gr[0:7])/gr[0:7]),exact[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='Black', label='Exact potentials')
# plt.errorbar(x[0:7],((param[0:7,0]-gr[0:7])/gr[0:7]),param[0:7,1]/gr[0:7],marker='.',markersize='10',fmt='o', color='Magenta',label='Potentials in new parameterization')
# plt.errorbar(x[0:7],((gr[0:7]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
# plt.errorbar(x[0:7],((approx[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o' , color='Red',label='Approximated potentials')
# plt.errorbar(x[0:7],((exact[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o', color='Black', label='Exact potentials')
# plt.errorbar(x[0:7],((param[0:7,0]-gr[0:7])/gr[0:7]),marker='.',markersize='10',fmt='o', color='Magenta',label='Potentials in new parameterization')

# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')
# plt.legend()
plt.xlim(10**-4,1.2*10**5)
plt.ylim(-0.3,+2.3)
# plt.ylim()
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$\alpha$",fontsize=16)
plt.ylabel(r"$\frac{\theta_{Theory}-\theta_{2nd}}{\theta_{2nd}}$",fontsize=16)
plt.xscale('log')
# plt.yscale('log')
plt.legend(loc='upper right', bbox_to_anchor=(0.8, 1),fontsize=6)
# plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
# plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
#             size='7')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('relative_error_all_comp.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
# plt.errorbar(x[0:7],((exact[0:7]-approx[0:7])/exact[0:7]),marker='.',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
plt.errorbar(x[:],((approx[:,0]-exact[:,0])/exact[:,0]),approx[:,1]/exact[:,0],marker='.',markersize='10',fmt='o', color='Blue', label=r"$\frac{\theta_{approx}-\theta_{exact}}{\theta_{exact}}$")
# plt.errorbar(x[0:7],(approx[0:7,0]-exact[0:7,0]),marker='.',markersize='10',fmt='o', color='Black', label='Exact potentials')
# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')
# plt.legend()
plt.xlim(10**-6,10**8)
plt.ylim(-2,2)
# plt.ylim()
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$\alpha$",fontsize=16)
plt.ylabel(r"$\frac{\theta_{approx}-\theta_{exact}}{\theta_{exact}}$",fontsize=16)
plt.xscale('log')
# plt.yscale('log')
plt.legend(loc='upper right', bbox_to_anchor=(1, 1),fontsize=14)
# plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
# plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
#             size='7')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('relative_error_approx.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
# plt.errorbar(x[0:7],((exact[0:7]-approx[0:7])/exact[0:7]),marker='.',markersize='10',fmt='o' ,color='Blue',label='GR-expected')
plt.errorbar(x[:],((param[:,0]-exact[:,0])/exact[:,0]),param[:,1]/exact[:,0],marker='.',markersize='10',fmt='o', color='Blue', label=r"$\frac{\theta_{param}-\theta_{exact}}{\theta_{exact}}$")
# plt.errorbar(x[0:7],(approx[0:7,0]-exact[0:7,0]),marker='.',markersize='10',fmt='o', color='Black', label='Exact potentials')
# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')
# plt.legend()
plt.xlim(10**-4,10**7)
# plt.ylim(-2,5)
# plt.ylim()
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$\alpha$",fontsize=16)
plt.ylabel(r"$\frac{\theta_{param}-\theta_{exact}}{\theta_{exact}}$",fontsize=16)
plt.xscale('log')
# plt.yscale('log')
plt.legend(loc='upper right', bbox_to_anchor=(1, 1),fontsize=14)
# plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
# plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
#             size='7')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('relative_error_param_.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
np.shape(anI)
# Out:
# (480770, 5)

# %%
SortI=anI[anI[:, 1].argsort()]
print(np.matrix(Sort[1:10]));

# %%
SortF=anF[anF[:, 1].argsort()]
# print(np.matrix(Sort[1:10]));

# %%
First_round_Perihelion=SortI[0][2]*60*60*180/np.pi
Last_round_Perihelion1=SortF[0][2]*60*60*180/np.pi

Last_round_Perihelion2=SortF[1][2]*60*60*180/np.pi
Last_round_Perihelion3=SortF[2][2]*60*60*180/np.pi
First_round_Perihelion;
Last_round_Perihelion1
Last_round_Perihelion2;
Last_round_Perihelion3;

# %%
plt.scatter(anI[:,2],anI[:,1],marker='o', color='blue', s=0.09,label='Round:1')
plt.scatter(anF[:,2],anF[:,1],marker='.', color='red', s=0.09,label='Round:415')
# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')

plt.legend()
plt.ylim(37, 80)
# plt.ylim(45.9999999,46.00000054)
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$\theta (rad)$",fontsize=16)
plt.ylabel(r"$r(\theta)$",fontsize=16)
plt.legend(loc='upper right', bbox_to_anchor=(1, 1),fontsize=8)
plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials", loc='right',fontsize=8)
# plt.ylim()
plt.figtext(0.34, 0.15, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
            size='7')#plt.ylim(-0.0005, 0.0003)
plt.savefig('10-2-1.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
plt.plot(anI[:,2],anI[:,1],'o',color='black',label='Round:1')
plt.plot(anF[:,2],anF[:,1],'o',color='red',label='Round:415')
plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')

plt.legend()
plt.xlim(-0.00001, 0.00002)
plt.ylim(45.999999999,46.000000001)
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$\theta (rad)$",fontsize=16)
plt.ylabel(r"$r(\theta)$",fontsize=16)
plt.legend(loc='upper right', bbox_to_anchor=(1, 1),fontsize=8)
plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials", loc='right',fontsize=8)
# plt.ylim()
plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
            size='9')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('10-2-2.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
plt.scatter(anI[:,3],anI[:,4],marker='.', color='blue', s=0.05,label='Round:1')
plt.scatter(anF[:,3],anF[:,4],marker='.', color='Red', s=0.05,label='Round:415')
# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')

plt.legend()
# plt.xlim(-90, 90)
# plt.ylim(45.999999999,46.000000001)
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$x (Gm)$",fontsize=16)
plt.ylabel(r"$y(Gm)$",fontsize=16)
plt.legend(loc='upper right', bbox_to_anchor=(1, 1),fontsize=8)
plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
plt.figtext(0.30, 0.45, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
            size='8')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('10-2-3.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
plt.scatter(anI[:,0],anI[:,1],marker='.', color='blue', s=0.05,label='Round:1')
plt.scatter(anF[:,0]-anF[1,0],anF[:,1],marker='.', color='Red', s=0.05,label='Round:415')
# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')

plt.legend()
# plt.xlim(-90, 90)
# plt.ylim(45.999999999,46.000000001)
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$t(Gs)$",fontsize=16)
plt.ylabel(r"$r(Gm)$",fontsize=16)
plt.legend(loc='upper right', bbox_to_anchor=(1, 1),fontsize=8)
plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
            size='7')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('10-2-4.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
x = matrix((10**-2, 10**-1, 10**0, 10**1, 10**2, 10**3))
exp = matrix((0.429679, 4.29679, 42.9679, 429.679, 4296.79, 42967.9))
app = matrix((2.4121, 2.71202, 34.9808, 357.712, 3589.15,35904.1))
exa = matrix((2.41014, 2.71117, 34.9845, 357.713, 3589.15, 
   35904.1))
param = matrix((-0.614117, 5.91875, 50.3443, 502.969, 5024.74, 
   50265.5 ))
x
# Out:
# matrix([[  1.00000000e-02,   1.00000000e-01,   1.00000000e+00,
#            1.00000000e+01,   1.00000000e+02,   1.00000000e+03]])

# %%
plt.scatter(x[:],((exp[:]-exp[:])/exp[:]), marker=".", s=50, color='red',label="GR")
plt.scatter(x[:],(app[:]-exp[:])/exp[:], marker=".", s=50,color='Magenta',label='Approximated potentials')
plt.scatter(x[:],(exa[:]-exp[:])/exp[:], marker=".", s=50, color='black',label='Exact potentials')
plt.scatter(x[:],(param[:]-exp[:])/exp[:],marker=".", s=50, color='Blue',label='Potentials in new parameterization')
# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')
# plt.legend()
plt.xlim(10**-6,10**5)
plt.ylim(-3,6)
# plt.ylim()
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$\alpha$",fontsize=16)
plt.ylabel(r"$\frac{\theta_{Theory}-\theta_{GR}}{\theta_{GR}}$",fontsize=16)
plt.xscale('log')
# plt.yscale('log')
plt.legend(loc='upper right', bbox_to_anchor=(1, 1),fontsize=9)
# plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
# plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
#             size='7')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('Compare2.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
plt.scatter(x[:],((exa[:]-app[:])/exa[:]), marker=".", s=50, color='Blue',label=r"$\frac{\theta_{exact}-\theta_{approx}}{\theta_{exact}}$")

# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')
# plt.legend()
plt.xlim(10**-6,10**5)
plt.ylim(-0.001,0.001)
# plt.ylim()
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$\alpha$",fontsize=16)
plt.ylabel(r"$\frac{\theta_{exact}-\theta_{approx}}{\theta_{exact}}$",fontsize=16)
plt.xscale('log')
# plt.yscale('log')
plt.legend(loc='upper right', bbox_to_anchor=(1, 1),fontsize=14)
# plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
# plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
#             size='7')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('Compare3.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
x1 = matrix((10**4, 10**5, 10**6, 10**7))
exp1 = matrix((429679, 4.29679e+06, 4.29679e+07,4.29679e+08))
app1 = matrix((-287993,  -160849, -184619, -184619))
exa1 = matrix(( -287993, -160880, -248804,-248804))
param1 = matrix((-143786, 118579,  225892, 225892 ))

# %%
plt.scatter(x1[:],exp1[:],marker='.', color='Blue', s=150,label='GR-expected')
plt.scatter(x1[:],app1[:],marker='.', color='Red', s=150,label='Approximated potentials')
plt.scatter(x1[:],exa1[:],marker='.', color='Black', s=150,label='Exact potentials')
plt.scatter(x1[:],param1[:],marker='.', color='Magenta', s=150,label='Potentials in new parameterization')


# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')

plt.legend()
# plt.xlim(-90, 90)
# plt.ylim(45.999999999,46.000000001)
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$\alpha$",fontsize=14)
plt.ylabel("Perihelion advance (Arcsec/415 orbits)",fontsize=14)
plt.xscale('log')
# plt.yscale('log')
plt.legend(loc='upper right', bbox_to_anchor=(0.5, 1),fontsize=8)
# plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
# plt.figtext(0.34, 0.25, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
#             size='7')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('Compare5N.jpg',bbox_inches='tight',dpi = 600)
plt.show()

# %%
anI=np.loadtxt("exact-result.txt")
anF=np.loadtxt("exact-result2.txt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-525-238635984129> in <module>()
# ----> 1 anI=np.loadtxt("exact-result.txt")
#       2 anF=np.loadtxt("exact-result2.txt")
#
# /Users/farbod/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# /Users/farbod/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
#     660
# ...

# %%
plt.scatter(anI[:,3],anI[:,4],marker='.', color='blue', s=0.05,label='Round:1')
plt.scatter(anF[:,3],anF[:,4],marker='.', color='Red', s=0.05,label='Round:415')
# plt.plot(anI[:,2],anI[:,1]-anI[:,1]+46,color='Blue',label='Minimum distance')

plt.legend()
# plt.xlim(-90, 90)
# plt.ylim(45.999999999,46.000000001)
# plt.savefig('EuRung75.jpg',bbox_inches='tight',dpi = 700)
# plt.xlabel('t')
# plt.ylabel(r'$x_{method}-x_{exact}$',fontsize='17')
# plt.legend(frameon=False)
#ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')
# ax.spines['left'].set_position(('data',0))
plt.xlabel(r"$x (Gm)$",fontsize=16)
plt.ylabel(r"$y(Gm)$",fontsize=16)
plt.legend(loc='upper right', bbox_to_anchor=(1, 1),fontsize=8)
plt.title(r"   $\alpha=10^{-2}$"+" , Exact potentials",fontsize=8)
# plt.ylim()
plt.figtext(0.30, 0.45, 'Perihelion-advance= ' +str(round(per,4))+ '$\pm $'+str(round(err,5))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$'+'\n'+'Expected perihelion= '+ str(round(0.429679,4))+r'$\frac{\textnormal{Arcsec}}{\textnormal{415 orbits}}$', color='black', weight='roman',
            size='8')
#plt.ylim(-0.0005, 0.0003)
plt.savefig('10-2-3.jpg',bbox_inches='tight',dpi = 600)
plt.show()
