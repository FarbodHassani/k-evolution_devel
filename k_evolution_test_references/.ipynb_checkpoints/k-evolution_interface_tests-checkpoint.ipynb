# %% [markdown]
# # k-evolution test notebook - implementing IC from class

# %%
import numpy as np
# import MAS_library as MASL
# import plotting_library as PL
from pylab import *
from matplotlib.colors import LogNorm
import matplotlib as plt
import pandas as pd
# import h5py as h5
import matplotlib.pyplot as plt
text_size=26
fig_size_x=24
fig_size_y=14
from collections import defaultdict

import seaborn as sns
Colors = sns.color_palette("colorblind", 30).as_hex()
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.interpolate import InterpolatedUnivariateSpline
from scipy import interpolate
import scipy.signal as sig
# from scipy.ndimage import gaussian_filter1

# %% [markdown]
# # Nested dictionary

# %%
def nested_dict(n, type):
    if n == 1:
        return defaultdict(type)
    else:
        return defaultdict(lambda: nested_dict(n-1, type))
    
data = nested_dict(5, list)

# %% [markdown]
# ## Background

# %%
As=2.215*1.e-9;
h=0.67556;
kp=0.05/h; 
ns=0.9619;
cs2_e3=1.e-7;
c=2.99792458*1.e5; #Km/s
Boxsize=320.;
c_gev=2997.92458; #[100km/s]
H0_conf_Gev=np.sqrt(Boxsize**2/c**2); #0.10677 rho_crit in Gev=1
H0=100*h/c; #H0 in 1/Mpc unit. 0.00022593979933110373
# print("H0[1/Mpc]=100h/c: ",H0);
w=-0.9;
# print("H0[1/Mpc]=100h/c: ",H0);
def Hubble_conf_Mpc(a):
    c=2.99792458*1.e5;h=0.67556;H0=100*h/c;w=-0.9;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0;
    Omega_rad=9.1671353942930788e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_kessence*(a**(-3*(1+w))))*a

# %%
redshifts = [100, 50, 30,20, 10, 9, 8, 7, 6 , 5, 4, 3, 2.5, 2, 1.5, 1, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.05, 0.01, 0]

address_kev_old = "./unity_c_s2_em7_wm0d9/k_evolution_lightcone_project_using_IC_file/"
for i in range(np.shape(redshifts)[0]):
    data['kev_file_lightcone']['bg'] = np.loadtxt(address_kev_old+"data__background.dat")
    data['kev_file_lightcone']['pow_phi']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_phi.dat")
    data['kev_file_lightcone']['pow_cdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_deltacdm.dat")
#     data['kev_old']['pow_ncdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_deltancdm.dat")
    data['kev_file_lightcone']['pow_B']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_B.dat")
    data['kev_file_lightcone']['pow_pk']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_pi_k.dat")
    data['kev_file_lightcone']['pow_zeta']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_zeta.dat")
    data['kev_file_lightcone']['pow_delta_kess']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_delta_kess.dat")


address_kev_old = "./unity_c_s2_em7_wm0d9/k_evolution_devel_file//"
for i in range(np.shape(redshifts)[0]):
    data['kev_file']['bg'] = np.loadtxt(address_kev_old+"data_background.dat")
    data['kev_file']['pow_phi']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_phi.dat")
    data['kev_file']['pow_cdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_deltacdm.dat")
#     data['kev_old']['pow_ncdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_deltancdm.dat")
    data['kev_file']['pow_B']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_B.dat")
    data['kev_file']['pow_pk']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_pi_k.dat")
    data['kev_file']['pow_zeta']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_zeta.dat")
    data['kev_file']['pow_delta_kess']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_delta_kess.dat")

# data['kev_old']['bg'] = np.loadtxt(address_kev_old+"data__background.dat")

#####################################

address_gev = "./unity_c_s2_em7_wm0d9//gevolution_devel/"

for i in range(np.shape(redshifts)[0]):
    data['gev']['pow_phi']['z='+str(redshifts[i])] = np.loadtxt(address_gev+"data_pk_"+str(i).zfill(3)+"_phi.dat")
    data['gev']['pow_cdm']['z='+str(redshifts[i])] = np.loadtxt(address_gev+"data_pk_"+str(i).zfill(3)+"_deltacdm.dat")
#     data['gev']['pow_ncdm']['z='+str(redshifts[i])] = np.loadtxt(address_gev+"data_pk_"+str(i).zfill(3)+"_deltancdm.dat")
    data['gev']['pow_B']['z='+str(redshifts[i])] = np.loadtxt(address_gev+"data_pk_"+str(i).zfill(3)+"_B.dat")
    data['gev']['pow_delta_kess']['z='+str(redshifts[i])] = np.loadtxt(address_gev+"data_pk_"+str(i).zfill(3)+"_deltaclass.dat")

data['gev']['bg'] = np.loadtxt(address_gev+"data__background.dat")

#####################################
address_kev_ref = "./unity_c_s2_em7_wm0d9/k_evolution_devel_interface_IC////"

for i in range(np.shape(redshifts)[0]):
    data['kev_ref']['pow_phi']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_phi.dat")
    data['kev_ref']['pow_cdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_deltacdm.dat")
#     data['kev']['pow_ncdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_deltancdm.dat")
    data['kev_ref']['pow_B']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_B.dat")
    data['kev_ref']['pow_pk']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_pi_k.dat")
    data['kev_ref']['pow_zeta']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_zeta.dat")
    data['kev_ref']['pow_delta_kess']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_delta_kess.dat")

data['kev_ref']['bg'] = np.loadtxt(address_kev_old+"data_background.dat")



address_kev_dev = "./../output////"

for i in range(np.shape(redshifts)[0]):
    data['kev']['pow_phi']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_phi.dat")
    data['kev']['pow_cdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_deltacdm.dat")
#     data['kev']['pow_ncdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_deltancdm.dat")
    data['kev']['pow_B']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_B.dat")
    data['kev']['pow_pk']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_pi_k.dat")
    data['kev']['pow_zeta']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_zeta.dat")
    data['kev']['pow_delta_kess']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_delta_kess.dat")

data['kev']['bg'] = np.loadtxt(address_kev_old+"data_background.dat")


address_class = "./unity_c_s2_em7_wm0d9/class_v2.7.1/"

for i in range(np.shape(redshifts)[0]):
    data['class']['tk']['z='+str(redshifts[i])] = np.loadtxt(address_class+"data_class_z"+str(i+1)+"_tk.dat")

data['class']['bg'] = np.loadtxt(address_class+"data_class_background.dat")

# %% [markdown]
# # Background test

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,10),nrows=2, ncols=1)
plt.subplots_adjust(hspace=0.09)
l=0
file_gev = data['gev']['bg']
f_gev = interpolate.interp1d(file_gev[:,2],file_gev[:,3])
axs[0].loglog(file_gev[:,2],file_gev[:,3],"-",color =Colors[l], lw=3,label="gevolution")

file = data['kev']['bg']
axs[0].loglog(file[:,2],file[:,3],"-",color =Colors[l+1], lw=3,label="kevolution")

file = data['kev_old']['bg']
axs[0].loglog(file[:,2],file[:,3],"-",color =Colors[l+3], lw=3,label="kevolution old")

file_class = data['class']['bg']
z = file_class[:,0]
a = 1./(1. + z )
f_class = interpolate.interp1d(a, file_class[:,3])

axs[0].loglog(a,file_class[:,3]*a*f_gev(1)/f_class(1),"-",color =Colors[l+2], lw=3,label="CLASS")

axs[0].set_ylabel(r'$\mathcal{H}$',fontsize=24)
axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_ylim(0.8,1.e1)
axs[0].set_xlim(1.e-2,2.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=20,bbox_to_anchor=[0.75,0.82],loc="center",frameon=False)



l=0
file_gev = data['gev']['bg']
# axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

file = data['kev']['bg']
# axs[1].plot(file[:,2],np.abs(file[:,3]-file_gev[:,3])/file_gev[:,3],"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

file = data['kev_old']['bg']
# axs[1].plot(file[:,2],np.abs(file[:,3]-file_gev[:,3])/file_gev[:,3],"-",color =Colors[l+2], lw=3,label="kevolution old vs gevolution")

file = data['kev_old']['bg']
num = np.shape(file_gev[:100,2])[0]-1
a  = file_gev[:num,2]
file_class = f_class(a)*a*f_gev(1)/f_class(1)
axs[1].plot(a,np.abs(file_class-file_gev[:num,3])/file_gev[:num,3],"-",color =Colors[l+3], lw=3,label="class vs gevolution")

axs[1].set_ylabel(r'$P_{l}(k)$',fontsize=24)
axs[1].set_xlabel('$a$',fontsize=24)
axs[1].set_xscale('log')
# axs[1].set_yscale('log')
axs[1].set_ylim(-0.01,0.01)
axs[1].set_xlim(1.e-2,2.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.75,0.82],loc="center",frameon=False)

# %% [markdown]
# ## Numerical background comparison

# %%
file1 = data['kev']['bg']
file2 = data['gev']['bg']
file3 = data['kev_old']['bg']
print(np.sum(file1-file2),np.sum( file1-file3), np.sum(file2 -file3)  )
if (np.sum(file1-file2)!=0 or np.sum( file1-file3)!= 0 or  np.sum(file2 -file3) !=0 ):
    print("\x1b[31m\"ERROR - Something is wrong! There is an inconsistency in the BG file\"\x1b[0m")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-286-8e545c116a3a> in <module>
#       2 file2 = data['gev']['bg']
#       3 file3 = data['kev_old']['bg']
# ----> 4 print(np.sum(file1-file2),np.sum( file1-file3), np.sum(file2 -file3)  )
#       5 if (np.sum(file1-file2)!=0 or np.sum( file1-file3)!= 0 or  np.sum(file2 -file3) !=0 ):
#       6     print("\x1b\"ERROR - Something is wrong! There is an inconsistency in the BG file\"\x1b")
#
# ValueError: operands could not be broadcast together with shapes (238,6) (357,6)

# %% [markdown]
# # Matter power spectrum CHECK

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,20),nrows=2, ncols=1)
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_cdm'

Normlization=As*(data['class']['tk']['z='+str(100)][:,0]/kp)**(ns-1.);

for redshift in [100, 1 ,0]:
    file = data['gev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"o",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+1], lw=3,label="kevolution")

    file = data['kev_file'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+2], lw=3,label="kevolution old")
    
    file = data['class']['tk']['z='+str(redshift)]
    delta_cdm = file[:,3]
    k = file[:,0]
    power = delta_cdm**2 * (Normlization)
    axs[0].loglog(k,power,":",color =Colors[l+2], lw=3,label="CLASS")
    l=l+3

axs[0].set_ylabel(r'$P$',fontsize=24)
axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
# axs[0].set_ylim(0.8,1.e1)
axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=20,bbox_to_anchor=[0.75,0.82],loc="center",frameon=False)


l=0
for redshift in [100,6,1,0]:
#     print(redshift)
    k = data['gev'][kind]['z='+str(redshift)] [:,0]
#     file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")
    file_kev_old = data['kev_file'][kind]['z='+str(redshift)][:,1]

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_kev_old)/file_kev_old,"-",color =Colors[l+1], lw=3,label="kevolution vs k-evolution old"+ 'z='+str(redshift))
#     axs[1].plot(k,np.abs(file_kev_old-file_gev)/file_gev,"-",color =Colors[l+2], lw=3,label="kevolution old vs gevolution"+ 'z='+str(redshift))
    l=l+2

axs[1].set_ylabel(r'$\Delta P(k)$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
# axs[1].set_yscale('log')
axs[1].set_ylim(-0.04,0.04)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.65,0.22],loc="center",frameon=False)

# %% [markdown]
# ## Numerical test

# %%
kind = 'pow_cdm'
for redshift in redshifts:

    k = data['gev'][kind]['z='+str(redshift)] [:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    
#     print("At z:"+ str(redshifts[i]) + "\n kevolution vs gevolution max of relative error: " +  str(np.max(file_kev-file_gev )) + " \n kevolution_old vs gevolution max of relative error: " + np.max(file_kev_old-file_gev ) + " \n kevolution_old vs kevolution max of relative error: " + np.max(file_kev_old-file_kev ) )
    max_kev_gev = np.max(np.abs(file_kev-file_gev )/file_gev)
    max_kev_old_gev = np.max(np.abs(file_kev_old-file_gev )/file_gev)
    max_kev_old_kev = np.max(np.abs(file_kev_old-file_kev )/file_kev)

    print("At z:"+ str(redshift) + "\n kevolution vs gevolution max of relative error: " +  str(max_kev_gev) + " at k=" + str(k[where(np.abs(file_kev-file_gev )/file_gev == max_kev_gev)])
         + " \n kevolution_old vs gevolution max of relative error: " + str(max_kev_old_gev)   + " at k=" + str(k[where(np.abs(file_kev_old-file_gev )/file_gev == max_kev_old_gev)])
          + " \n kevolution_old vs kevolution max of relative error: " + str(max_kev_old_kev)  + " at k=" + str(k[where(np.abs(file_kev_old-file_kev )/file_kev == max_kev_old_kev)]))
# Out:
# At z:100
#  kevolution vs gevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
#  kevolution_old vs gevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
#  kevolution_old vs kevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
# At z:50
#  kevolution vs gevolution max of relative error: 8.638995389108605e-07 at k=[0.02835132]
#  kevolution_old vs gevolution max of relative error: 8.638995389108605e-07 at k=[0.02835132]
#  kevolution_old vs kevolution max of relative error: 2.883677634259081e-07 at k=[0.05530002]
# At z:30
#  kevolution vs gevolution max of relative error: 9.79797554339059e-07 at k=[0.05033911]
#  kevolution_old vs gevolution max of relative error: 9.79797554339059e-07 at k=[0.05033911]
#  kevolution_old vs kevolution max of relative error: 6.751943715156973e-07 at k=[0.06285692]
# At z:20
#  kevolution vs gevolution max of relative error: 1.425182548081852e-06 at k=[0.07265895]
#  kevolution_old vs gevolution max of relative error: 1.425182548081852e-06 at k=[0.07265895]
#  kevolution_old vs kevolution max of relative error: 9.54419774865807e-07 at k=[0.00348453]
# At z:10
#  kevolution vs gevolution max of relative error: 1.1668806247019404e-05 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 1.1668806247019404e-05 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 9.473599446627153e-07 at k=[0.0718439]
# At z:9
#  kevolution vs gevolution max of relative error: 1.715913380700926e-05 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 1.715913380700926e-05 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 9.728336210661576e-07 at k=[0.03801175]
# At z:8
#  kevolution vs gevolution max of relative error: 2.5824252019996457e-05 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 2.5824252019996457e-05 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 9.87114211141828e-07 at k=[0.06103403]
# At z:7
#  kevolution vs gevolution max of relative error: 4.098214184444465e-05 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 4.1089144825795825e-05 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 9.937493167195586e-07 at k=[0.06040412]
# At z:6
#  kevolution vs gevolution max of relative error: 6.865070088885619e-05 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 6.865070088885619e-05 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 9.915214997258e-07 at k=[0.01790385]
# At z:5
#  kevolution vs gevolution max of relative error: 0.00012478180419322134 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.00012478180419322134 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 9.55452048301993e-07 at k=[0.06590463]
# At z:4
#  kevolution vs gevolution max of relative error: 0.0002478891024665913 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0002478891024665913 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 9.85677125609493e-07 at k=[0.07231197]
# At z:3
#  kevolution vs gevolution max of relative error: 0.0005656694480351082 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0005660545191366845 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 9.988742687267487e-07 at k=[0.05767223]
# At z:2.5
#  kevolution vs gevolution max of relative error: 0.0009014389041523681 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0009020681808742298 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 1.002511793285977e-06 at k=[0.07763548]
# At z:2
#  kevolution vs gevolution max of relative error: 0.0014893617021278116 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.001490081316414585 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 1.0342930193370378e-06 at k=[0.07930658]
# At z:1.5
#  kevolution vs gevolution max of relative error: 0.0024600009184761146 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0024611056148084675 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 1.485181232934932e-06 at k=[0.08200132]
# At z:1
#  kevolution vs gevolution max of relative error: 0.004280030711244504 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.004281426676903763 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 1.8770495034038398e-06 at k=[0.07763548]
# At z:0.9
#  kevolution vs gevolution max of relative error: 0.005011158553362338 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.005012856963310923 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 1.956820792371332e-06 at k=[0.08133227]
# At z:0.8
#  kevolution vs gevolution max of relative error: 0.005886587225251475 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.00588813358033778 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 1.9661024280144017e-06 at k=[0.07567131]
# At z:0.7
#  kevolution vs gevolution max of relative error: 0.0069274709461138746 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.006928876255160548 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 2.0482079887142863e-06 at k=[0.0828117]
# At z:0.6
#  kevolution vs gevolution max of relative error: 0.00825217470141106 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.008253765267445671 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 2.3316309836683794e-06 at k=[0.07769801]
# At z:0.5
#  kevolution vs gevolution max of relative error: 0.009842703673506883 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.009844716790401387 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 2.9711972142350765e-06 at k=[0.08375931]
# At z:0.4
#  kevolution vs gevolution max of relative error: 0.011821204093563298 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.011823019628002165 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 2.4042384319025585e-06 at k=[0.08461027]
# At z:0.3
#  kevolution vs gevolution max of relative error: 0.014306085535912196 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.014308186008518615 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 2.629415445774488e-06 at k=[0.06856651]
# At z:0.2
#  kevolution vs gevolution max of relative error: 0.01739167270806327 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.01739376980842352 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 2.912704781379536e-06 at k=[0.08375931]
# At z:0.1
#  kevolution vs gevolution max of relative error: 0.0212344822873743 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.021237117632586636 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 3.1351746212813803e-06 at k=[0.08461027]
# At z:0.05
#  kevolution vs gevolution max of relative error: 0.023507267895883012 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.023509942276175685 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 3.272011169702611e-06 at k=[0.08461027]
# At z:0.01
#  kevolution vs gevolution max of relative error: 0.025523037050225204 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.0255257682473413 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 3.41915702389016e-06 at k=[0.08461027]
# At z:0
#  kevolution vs gevolution max of relative error: 0.2695682980729893 at k=[0.0791073]
#  kevolution_old vs gevolution max of relative error: 0.02634133185894234 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.21814664019516197 at k=[0.0791073]

# %% [markdown]
# # Potential power spectrum

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,20),nrows=2, ncols=1,gridspec_kw={'height_ratios': [1, 2]})
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_phi'
Normlization=As*(data['class']['tk']['z='+str(100)][:,0]/kp)**(ns-1.);

for redshift in [100, 0]:
    file = data['gev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"o",color =Colors[l+1], lw=3,label="kevolution" + 'z='+str(redshift))

    file = data['kev_file'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+2], lw=3,label="kevolution file" + 'z='+str(redshift))
    
#     file = data['class']['tk']['z='+str(redshift)]
#     delta = file[:,9]
#     k = file[:,0]
#     power = delta**2 * (Normlization)
#     axs[0].loglog(k,power,":",color =Colors[l+2], lw=3,label="CLASS")
    l=l+3

axs[0].set_ylabel(r'$P_{\Phi}$',fontsize=24)
# axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_ylim(1.e-14,1.e-8)
axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=18,bbox_to_anchor=[0.25,0.22],ncol=2,loc="center",frameon=False)


l=0
for redshift in [100, 0.01,0]:
#     print(redshift)
    k = data['gev'][kind]['z='+str(redshift)] [:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
#     axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")
    file_kev_old = data['kev_file'][kind]['z='+str(redshift)][:,1]

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_kev_old)/file_kev_old,"-",color =Colors[l+1], lw=3,label="kev-kev file"+ ', z='+str(redshift))

    axs[1].plot(k,np.abs(file_kev_old-file_gev)/file_gev,"o",markersize=10,color =Colors[l+2], lw=3,label="kev-file vs gev"+ ', z='+str(redshift))

    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"o",markersize=10,color =Colors[l+3], lw=3,label="kev vs gev"+ ', z='+str(redshift))

    l=l+3

axs[1].set_ylabel(r'$\Delta$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
# axs[1].set_yscale('log')
axs[1].set_ylim(-0.01,0.2)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.5,0.82],ncol=3,loc="center",frameon=False)

# %% [markdown]
# ## Numerical test

# %%
kind = 'pow_phi'
for redshift in redshifts:

    k = data['gev'][kind]['z='+str(redshift)] [:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    
#     print("At z:"+ str(redshifts[i]) + "\n kevolution vs gevolution max of relative error: " +  str(np.max(file_kev-file_gev )) + " \n kevolution_old vs gevolution max of relative error: " + np.max(file_kev_old-file_gev ) + " \n kevolution_old vs kevolution max of relative error: " + np.max(file_kev_old-file_kev ) )
    max_kev_gev = np.max(np.abs(file_kev-file_gev )/file_gev)
    max_kev_old_gev = np.max(np.abs(file_kev_old-file_gev )/file_gev)
    max_kev_old_kev = np.max(np.abs(file_kev_old-file_kev )/file_kev)

    print("At z:"+ str(redshift) + "\n kevolution vs gevolution max of relative error: " +  str(max_kev_gev) + " at k=" + str(k[where(np.abs(file_kev-file_gev )/file_gev == max_kev_gev)])
         + " \n kevolution_old vs gevolution max of relative error: " + str(max_kev_old_gev)   + " at k=" + str(k[where(np.abs(file_kev_old-file_gev )/file_gev == max_kev_old_gev)])
          + " \n kevolution_old vs kevolution max of relative error: " + str(max_kev_old_kev)  + " at k=" + str(k[where(np.abs(file_kev_old-file_kev )/file_kev == max_kev_old_kev)]))
# Out:
# At z:100
#  kevolution vs gevolution max of relative error: 2.314739806674753 at k=[0.07095108]
#  kevolution_old vs gevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
#  kevolution_old vs kevolution max of relative error: 3.940011114050224 at k=[0.07589562]
# At z:50
#  kevolution vs gevolution max of relative error: 9.835621235827301e-05 at k=[0.0051684]
#  kevolution_old vs gevolution max of relative error: 1.8759332767926277e-06 at k=[0.08192725]
#  kevolution_old vs kevolution max of relative error: 9.83465393651625e-05 at k=[0.0051684]
# At z:30
#  kevolution vs gevolution max of relative error: 0.0001475345551366206 at k=[0.00155833]
#  kevolution_old vs gevolution max of relative error: 8.416875836110614e-06 at k=[0.08200132]
#  kevolution_old vs kevolution max of relative error: 0.00014730932598256007 at k=[0.00155833]
# At z:20
#  kevolution vs gevolution max of relative error: 0.0003360380296697508 at k=[0.0557525]
#  kevolution_old vs gevolution max of relative error: 2.8362640117216706e-05 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.00032079906067013854 at k=[0.0557525]
# At z:10
#  kevolution vs gevolution max of relative error: 0.0020288903894333126 at k=[0.08458156]
#  kevolution_old vs gevolution max of relative error: 0.0003414106262760023 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0019444838064648525 at k=[0.08458156]
# At z:9
#  kevolution vs gevolution max of relative error: 0.002690383836800827 at k=[0.08458156]
#  kevolution_old vs gevolution max of relative error: 0.00048642976848775 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.002588082057961588 at k=[0.08458156]
# At z:8
#  kevolution vs gevolution max of relative error: 0.0036113416668761837 at k=[0.08458156]
#  kevolution_old vs gevolution max of relative error: 0.0007147090432978038 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0034824395245922042 at k=[0.08458156]
# At z:7
#  kevolution vs gevolution max of relative error: 0.0049756648354044655 at k=[0.08458156]
#  kevolution_old vs gevolution max of relative error: 0.0010952397557052588 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.004805565277771793 at k=[0.08458156]
# At z:6
#  kevolution vs gevolution max of relative error: 0.007092360474764832 at k=[0.08458156]
#  kevolution_old vs gevolution max of relative error: 0.0017716801105869973 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.006850780850076079 at k=[0.08458156]
# At z:5
#  kevolution vs gevolution max of relative error: 0.010517202047406865 at k=[0.08458156]
#  kevolution_old vs gevolution max of relative error: 0.0030603778723338067 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.010141482020243469 at k=[0.08458156]
# At z:4
#  kevolution vs gevolution max of relative error: 0.016447316945472138 at k=[0.08458156]
#  kevolution_old vs gevolution max of relative error: 0.005785725667862427 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.01578429268413613 at k=[0.08458156]
# At z:3
#  kevolution vs gevolution max of relative error: 0.028055543965867576 at k=[0.08458156]
#  kevolution_old vs gevolution max of relative error: 0.012444795324152543 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.026636804665687082 at k=[0.08458156]
# At z:2.5
#  kevolution vs gevolution max of relative error: 0.03803477474583032 at k=[0.08278237]
#  kevolution_old vs gevolution max of relative error: 0.019464371567357433 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.03567147533205037 at k=[0.08458156]
# At z:2
#  kevolution vs gevolution max of relative error: 0.054683775805801145 at k=[0.08278237]
#  kevolution_old vs gevolution max of relative error: 0.03227896652125845 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.05041650686174284 at k=[0.08278237]
# At z:1.5
#  kevolution vs gevolution max of relative error: 0.08089767752986145 at k=[0.08278237]
#  kevolution_old vs gevolution max of relative error: 0.057437140918646615 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.07278065368835522 at k=[0.08278237]
# At z:1
#  kevolution vs gevolution max of relative error: 0.13209349178796867 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.11091556637578033 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.10508571741381847 at k=[0.08278237]
# At z:0.9
#  kevolution vs gevolution max of relative error: 0.15296196052948147 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.12792084143847945 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.1130577652737918 at k=[0.08278237]
# At z:0.8
#  kevolution vs gevolution max of relative error: 0.1775835123295686 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.14793645661142255 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.12100210832815207 at k=[0.08278237]
# At z:0.7
#  kevolution vs gevolution max of relative error: 0.20654543843181206 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.17143130914593224 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.13419383418399936 at k=[0.08133227]
# At z:0.6
#  kevolution vs gevolution max of relative error: 0.24105644714244218 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.1993918264551942 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.1487991845671676 at k=[0.08133227]
# At z:0.5
#  kevolution vs gevolution max of relative error: 0.2814249294184802 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.23209176936283404 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.16260307698233603 at k=[0.08133227]
# At z:0.4
#  kevolution vs gevolution max of relative error: 0.32869011822386457 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.2704397317924381 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.17482044132279193 at k=[0.08133227]
# At z:0.3
#  kevolution vs gevolution max of relative error: 0.38353630698613334 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.31511949118388694 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.18474610713265857 at k=[0.08133227]
# At z:0.2
#  kevolution vs gevolution max of relative error: 0.446059216364733 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.36643801569433937 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.19104028361862752 at k=[0.08133227]
# At z:0.1
#  kevolution vs gevolution max of relative error: 0.5159345515208914 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.42450652345308093 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.19227512920217374 at k=[0.08133227]
# At z:0.05
#  kevolution vs gevolution max of relative error: 0.5533155773355936 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.4559924263914356 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.21787899019097148 at k=[0.04527209]
# At z:0.01
#  kevolution vs gevolution max of relative error: 0.5824594925981167 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.48010579962786054 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.24513476215073085 at k=[0.04527209]
# At z:0
#  kevolution vs gevolution max of relative error: 0.24244429483471658 at k=[0.0791073]
#  kevolution_old vs gevolution max of relative error: 0.126481505116536 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.254880836025658 at k=[0.04527209]

# %% [markdown]
# # B power spectrum

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,20),nrows=2, ncols=1,gridspec_kw={'height_ratios': [1, 3]})
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_B'
for redshift in [100, 1 ,0.01]:
#     file = data['gev'][kind]['z='+str(redshift)] 
#     axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"o",color =Colors[l+1], lw=3,label="kevolution")

    file = data['kev_file'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+2], lw=3,label="kevolution file")
    l=l+3

axs[0].set_ylabel(r'$P_{\Phi}$',fontsize=24)
# axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
# axs[0].set_ylim(0.8,1.e1)
axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=18,bbox_to_anchor=[0.95,0.82],loc="center",frameon=False)


l=0
for redshift in [100, 6,1,0.01]:
#     print(redshift)
    k = data['gev'][kind]['z='+str(redshift)] [:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")
    file_kev_old = data['kev_file'][kind]['z='+str(redshift)][:,1]

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_kev_old)/file_kev_old,"-",color =Colors[l+1], lw=3,label="kev-kev file "+ ', z='+str(redshift))

    axs[1].plot(file[:,2],np.abs(file_kev_old-file_gev)/file_gev,"o",markersize=10,color =Colors[l+2], lw=3,label="kev-file vs gev"+ ', z='+str(redshift))
    l=l+3

axs[1].set_ylabel(r'$\Delta$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
# axs[1].set_yscale('log')
axs[1].set_ylim(-0.01,0.2)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.5,0.82],ncol=3,loc="center",frameon=False)

# %% [markdown]
# # delta kess

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,25),nrows=2, ncols=1,gridspec_kw={'height_ratios': [1, 2]})
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_delta_kess'
Normlization=As*(data['class']['tk']['z='+str(100)][:,0]/kp)**(ns-1.);

for redshift in [100,0.01]:
#     file = data['gev'][kind]['z='+str(redshift)] 
#     k = file[:,0]
#     axs[0].loglog(k,file[:,1],"-",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"o",markersize = 9, color =Colors[l], lw=3,label="kevolution"+ ', z='+str(redshift))

    file = data['kev_old'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l], lw=3,label="kevolution old"+ ', z='+str(redshift))
    
    file = data['class']['tk']['z='+str(redshift)]
    delta = file[:,4]
    k = file[:,0]
    power = delta**2 * (Normlization)
    axs[0].loglog(k,power,":",color =Colors[l], lw=3,label="CLASS"+ ', z='+str(redshift))
    
    l=l+3

axs[0].set_ylabel(r'$P_{\Delta_kess}$',fontsize=24)
# axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_ylim(1.e-11,1.e-4)
axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=20,bbox_to_anchor=[0.75,0.72],loc="center",frameon=False)


l=0
for redshift in [100,1,0.01,0]:
#     print(redshift)
    k = data['gev'][kind]['z='+str(redshift)][:,0]
#     file_gev = data['gev'][kind]['z='+str(redshift)][:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")
    
    
    
    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
#     axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kev-gev"+ ', z='+str(redshift))

    
#     file = data['class']['tk']['z='+str(redshift)]
#     delta = file[:,4]
#     k_class = file[:,0]
#     power = delta**2 * (Normlization)
#     f_kess_class = interpolate.interp1d(k_class, power)
#     file_class = f_kess_class(k)
#     axs[1].plot(k,np.abs(file_class-file_kev)/file_kev,":",color =Colors[l+3], lw=3,label="class-kev"+ ', z='+str(redshift))


    file_kev_old = data['kev_file'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev_old-file_kev)/(2.0 * (file_kev+ file_kev_old)),"o",markersize=10,color =Colors[l+2], lw=3,label="kev-file vs kev"+ ', z='+str(redshift))
    l=l+3

axs[1].set_ylabel(r'$\Delta$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[1].set_ylim(1.e-4,1)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.5,0.82],ncol=3,loc="center",frameon=False)

# %% [markdown]
# ## Numerical test:

# %%
kind = 'pow_B'
for redshift in redshifts:

    k = data['kev'][kind]['z='+str(redshift)] [:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
#     axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    
    
    file = data['class']['tk']['z='+str(redshift)]
    delta = file[:,4]
    k_class = file[:,0]
    power = delta**2 * (Normlization)
    f_kess_class = interpolate.interp1d(k_class, power)
    file_class = f_kess_class(k)

#     print("At z:"+ str(redshifts[i]) + "\n kevolution vs gevolution max of relative error: " +  str(np.max(file_kev-file_gev )) + " \n kevolution_old vs gevolution max of relative error: " + np.max(file_kev_old-file_gev ) + " \n kevolution_old vs kevolution max of relative error: " + np.max(file_kev_old-file_kev ) )
    max_kev_gev = np.max(np.abs(file_kev-file_gev )/file_gev)
    max_kev_old_gev = np.max(np.abs(file_kev_old-file_gev )/file_gev)
    max_kev_old_kev = np.max(np.abs(file_kev_old-file_kev )/file_kev)
    max_class_kev = np.max(np.abs(file_class-file_kev )/file_kev)

    

    print("At z:"+ str(redshift) + "\n kevolution vs gevolution max of relative error: " +  str(max_kev_gev) + " at k=" + str(k[where(np.abs(file_kev-file_gev )/file_gev == max_kev_gev)])
         + " \n kevolution_old vs gevolution max of relative error: " + str(max_kev_old_gev)   + " at k=" + str(k[where(np.abs(file_kev_old-file_gev )/file_gev == max_kev_old_gev)])
#          + " \n class vs kevolution max of relative error: " + str(max_class_kev)   + " at k=" + str(k[where(np.abs(file_class-file_kev )/file_kev == max_class_kev)])
          + " \n kevolution_old vs kevolution max of relative error: " + str(max_kev_old_kev)  + " at k=" + str(k[where(np.abs(file_kev_old-file_kev )/file_kev == max_kev_old_kev)]))
# Out:
# At z:100
#  kevolution vs gevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
#  kevolution_old vs gevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
#  kevolution_old vs kevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
# At z:50
#  kevolution vs gevolution max of relative error: 9.864549866201594e-07 at k=[0.0764782]
#  kevolution_old vs gevolution max of relative error: 9.864549866201594e-07 at k=[0.0764782]
#  kevolution_old vs kevolution max of relative error: 8.09466221700653e-07 at k=[0.05483018]
# At z:30
#  kevolution vs gevolution max of relative error: 1.2701106139000045e-06 at k=[0.08011391]
#  kevolution_old vs gevolution max of relative error: 1.4734104663384365e-06 at k=[0.0449491]
#  kevolution_old vs kevolution max of relative error: 8.776402711290482e-07 at k=[0.05522734]
# At z:20
#  kevolution vs gevolution max of relative error: 5.851228611749822e-06 at k=[0.08548117]
#  kevolution_old vs gevolution max of relative error: 5.851228611749822e-06 at k=[0.08548117]
#  kevolution_old vs kevolution max of relative error: 8.873838857987793e-07 at k=[0.01902184]
# At z:10
#  kevolution vs gevolution max of relative error: 6.80632557498269e-05 at k=[0.08548117]
#  kevolution_old vs gevolution max of relative error: 6.849403584948291e-05 at k=[0.08548117]
#  kevolution_old vs kevolution max of relative error: 9.921294371527977e-07 at k=[0.03463561]
# At z:9
#  kevolution vs gevolution max of relative error: 8.863426288920826e-05 at k=[0.08548117]
#  kevolution_old vs gevolution max of relative error: 8.863426288920826e-05 at k=[0.08548117]
#  kevolution_old vs kevolution max of relative error: 9.846628909461262e-07 at k=[0.04391505]
# At z:8
#  kevolution vs gevolution max of relative error: 0.00012550175802065257 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.00012550175802065257 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 9.807459946444874e-07 at k=[0.07618304]
# At z:7
#  kevolution vs gevolution max of relative error: 0.0001937859970237888 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0001937859970237888 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 9.955974679743484e-07 at k=[0.02468859]
# At z:6
#  kevolution vs gevolution max of relative error: 0.0003140140565089974 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.000314687906415714 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 9.736975092716342e-07 at k=[0.05530002]
# At z:5
#  kevolution vs gevolution max of relative error: 0.0005432526626344685 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0005441812996646747 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 9.97620674552078e-07 at k=[0.07522069]
# At z:4
#  kevolution vs gevolution max of relative error: 0.0010274457198869843 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0010281221160159872 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 9.968996421543405e-07 at k=[0.06791887]
# At z:3
#  kevolution vs gevolution max of relative error: 0.002185579217836227 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0021864298860147925 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 1.3486558621503078e-06 at k=[0.0764782]
# At z:2.5
#  kevolution vs gevolution max of relative error: 0.003380096417319607 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0033812055547821932 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 1.4833813083181827e-06 at k=[0.07864549]
# At z:2
#  kevolution vs gevolution max of relative error: 0.005489472344652786 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.005490967298994973 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 2.0151539578357754e-06 at k=[0.08038625]
# At z:1.5
#  kevolution vs gevolution max of relative error: 0.009437674933520728 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.009439251207031383 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 2.290726395221938e-06 at k=[0.0805673]
# At z:1
#  kevolution vs gevolution max of relative error: 0.018578938266692192 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.01858191345547714 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 3.134823262501583e-06 at k=[0.04296018]
# At z:0.9
#  kevolution vs gevolution max of relative error: 0.02154004486184809 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.021543223735056814 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 3.419370391372763e-06 at k=[0.04296018]
# At z:0.8
#  kevolution vs gevolution max of relative error: 0.025054857251635577 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.025058271824777725 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 3.746237372885677e-06 at k=[0.04296018]
# At z:0.7
#  kevolution vs gevolution max of relative error: 0.02923054072579562 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.02923423086822597 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 3.8012551745374896e-06 at k=[0.0805673]
# At z:0.6
#  kevolution vs gevolution max of relative error: 0.03419950455728985 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.03420352111756777 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 4.158788794242291e-06 at k=[0.0805673]
# At z:0.5
#  kevolution vs gevolution max of relative error: 0.04009314401837311 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.04009755215932771 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 4.592259058397381e-06 at k=[0.0805673]
# At z:0.4
#  kevolution vs gevolution max of relative error: 0.04705446235380408 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.04705934802005321 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 5.1269102547035796e-06 at k=[0.0805673]
# At z:0.3
#  kevolution vs gevolution max of relative error: 0.05520117796116848 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.055205971989179176 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 5.074125728003756e-06 at k=[0.0805673]
# At z:0.2
#  kevolution vs gevolution max of relative error: 0.06465319452440693 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.06465864799191635 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 5.830422980532388e-06 at k=[0.0805673]
# At z:0.1
#  kevolution vs gevolution max of relative error: 0.07548320345375345 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.07548861572933573 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 5.854166849639112e-06 at k=[0.0805673]
# At z:0.05
#  kevolution vs gevolution max of relative error: 0.08140725397320833 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.08141302678093576 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 6.284403782198673e-06 at k=[0.0805673]
# At z:0.01
#  kevolution vs gevolution max of relative error: 0.08638004079711294 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.086385914507309 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 6.429051967279014e-06 at k=[0.0805673]
# At z:0
#  kevolution vs gevolution max of relative error: 0.33234045947364055 at k=[0.08097319]
#  kevolution_old vs gevolution max of relative error: 0.0958196526421834 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.18405353798152804 at k=[0.08548117]

# %% [markdown]
# # pi_k power spectrum

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,20),nrows=2, ncols=1,gridspec_kw={'height_ratios': [1, 3]})
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_pk'
for redshift in [100,6,1]:
#     file = data['gev'][kind]['z='+str(redshift)] 
#     axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"o",color =Colors[l+1], lw=3,label="kevolution"+ ', z='+str(redshift))

    file = data['kev_old'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+2], lw=3,label="kevolution old"+ ', z='+str(redshift))
    
    file = data['class']['tk']['z='+str(redshift)]
    delta = file[:,14]
    k = file[:,0]
    power = (delta/(k*h)**2)**2 * (Normlization)*Hubble_conf_Mpc(1./(1+redshift))**2
    axs[0].loglog(k,power,":",color =Colors[l], lw=3,label="CLASS"+ ', z='+str(redshift))

    
    l=l+3

axs[0].set_ylabel(r'$P_{\pi_k}$',fontsize=24)
# axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_ylim(1.e-11,1.e-9)

axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=18,bbox_to_anchor=[0.95,0.82],loc="center",frameon=False)


l=0
for redshift in [100, 6,1, 0.5,0.01,0]:
#     print(redshift)
    k = data['kev'][kind]['z='+str(redshift)] [:,0]
#     file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
#     # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
#     axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kev-gev"+ ', z='+str(redshift))

    file_kev_old = data['kev_file'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev_old-file_kev)/(2.0*(file_kev+file_kev_old)),"o",markersize=10,color =Colors[l+2], lw=3,label="kev-file vs kev"+ ', z='+str(redshift))
    l=l+3

axs[1].set_ylabel(r'$\Delta$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[1].set_ylim(1.e-5,0.04)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.5,0.82],ncol=3,loc="center",frameon=False)

# %% [markdown]
# ## numerical check

# %%
kind = 'pow_pk'
for redshift in redshifts:

#     k = data['gev'][kind]['z='+str(redshift)] [:,0]
#     file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    
#     print("At z:"+ str(redshifts[i]) + "\n kevolution vs gevolution max of relative error: " +  str(np.max(file_kev-file_gev )) + " \n kevolution_old vs gevolution max of relative error: " + np.max(file_kev_old-file_gev ) + " \n kevolution_old vs kevolution max of relative error: " + np.max(file_kev_old-file_kev ) )
    max_kev_gev = np.max(np.abs(file_kev-file_gev )/file_gev)
    max_kev_old_gev = np.max(np.abs(file_kev_old-file_gev )/file_gev)
    max_kev_old_kev = np.max(np.abs(file_kev_old-file_kev )/file_kev)

    print("At z:"+ str(redshift) + " \n kevolution_old vs kevolution max of relative error: " + str(max_kev_old_kev)  + " at k=" + str(k[where(np.abs(file_kev_old-file_kev )/file_kev == max_kev_old_kev)]))
# Out:
# At z:100
#  kevolution_old vs kevolution max of relative error: 4.258414449087185 at k=[0.07841356]
# At z:50
#  kevolution_old vs kevolution max of relative error: 0.012026885803328691 at k=[0.02159285]
# At z:30
#  kevolution_old vs kevolution max of relative error: 0.0063233424186806605 at k=[0.04527209]
# At z:20
#  kevolution_old vs kevolution max of relative error: 0.004163423607918764 at k=[0.04527209]
# At z:10
#  kevolution_old vs kevolution max of relative error: 0.002163747263059088 at k=[0.04527209]
# At z:9
#  kevolution_old vs kevolution max of relative error: 0.0019704535494045445 at k=[0.04527209]
# At z:8
#  kevolution_old vs kevolution max of relative error: 0.0017768195315395 at k=[0.04527209]
# At z:7
#  kevolution_old vs kevolution max of relative error: 0.001584753098711632 at k=[0.04527209]
# At z:6
#  kevolution_old vs kevolution max of relative error: 0.0013934417912020822 at k=[0.04527209]
# At z:5
#  kevolution_old vs kevolution max of relative error: 0.0012020027682309244 at k=[0.04527209]
# At z:4
#  kevolution_old vs kevolution max of relative error: 0.0010106019581816936 at k=[0.04527209]
# At z:3
#  kevolution_old vs kevolution max of relative error: 0.0008193776766001474 at k=[0.04527209]
# At z:2.5
#  kevolution_old vs kevolution max of relative error: 0.0007238116891363689 at k=[0.04527209]
# At z:2
#  kevolution_old vs kevolution max of relative error: 0.0006288221615657903 at k=[0.04527209]
# At z:1.5
#  kevolution_old vs kevolution max of relative error: 0.000533947714811437 at k=[0.04527209]
# At z:1
#  kevolution_old vs kevolution max of relative error: 0.00044068794829040686 at k=[0.04527209]
# At z:0.9
#  kevolution_old vs kevolution max of relative error: 0.0004227709507315826 at k=[0.04527209]
# At z:0.8
#  kevolution_old vs kevolution max of relative error: 0.00040457712752861135 at k=[0.04527209]
# At z:0.7
#  kevolution_old vs kevolution max of relative error: 0.0003865599264412954 at k=[0.04527209]
# At z:0.6
#  kevolution_old vs kevolution max of relative error: 0.0003685551852577856 at k=[0.04527209]
# At z:0.5
#  kevolution_old vs kevolution max of relative error: 0.00035123065454171 at k=[0.04527209]
# At z:0.4
#  kevolution_old vs kevolution max of relative error: 0.00033356294950737445 at k=[0.04527209]
# At z:0.3
#  kevolution_old vs kevolution max of relative error: 0.0003165061645095716 at k=[0.04527209]
# At z:0.2
#  kevolution_old vs kevolution max of relative error: 0.00030016188896583797 at k=[0.04527209]
# At z:0.1
#  kevolution_old vs kevolution max of relative error: 0.0002840729279994066 at k=[0.04527209]
# At z:0.05
#  kevolution_old vs kevolution max of relative error: 0.000276937667108901 at k=[0.04527209]
# At z:0.01
#  kevolution_old vs kevolution max of relative error: 0.00026993599086892105 at k=[0.04527209]
# At z:0
#  kevolution_old vs kevolution max of relative error: 0.17932900058262566 at k=[0.08278237]

# %% [markdown]
# # zeta power

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,20),nrows=2, ncols=1,gridspec_kw={'height_ratios': [1, 3]})
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_zeta'
for redshift in [100,6,1,0]:
#     file = data['gev'][kind]['z='+str(redshift)] 
#     axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"o",color =Colors[l+1], lw=3,label="kevolution"+ ', z='+str(redshift))

    file = data['kev_file'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+2], lw=3,label="kevolution file"+ ', z='+str(redshift))
    l=l+3

axs[0].set_ylabel(r'$P_{\zeta}$',fontsize=24)
# axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_ylim(1.e-29,1.e-14)
axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=18,bbox_to_anchor=[0.95,0.82],loc="center",frameon=False)


l=0
for redshift in [100,6,1,0]:
#     print(redshift)
    k = data['kev'][kind]['z='+str(redshift)] [:,0]
#     file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
#     # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
#     axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kev-gev"+ ', z='+str(redshift))

    file_kev_old = data['kev_file'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev_old-file_kev)/(2.0*(file_kev+file_kev)),"o",markersize=10,color =Colors[l+2], lw=3,label="kev-file vs kev"+ ', z='+str(redshift))
    l=l+3

axs[1].set_ylabel(r'$\Delta$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[1].set_ylim(1.e-5,0.04)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.5,0.82],ncol=3,loc="center",frameon=False)

# %% [markdown]
# ## Numerical check

# %%
kind = 'pow_zeta'
for redshift in redshifts:

#     k = data['gev'][kind]['z='+str(redshift)] [:,0]
#     file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    
#     print("At z:"+ str(redshifts[i]) + "\n kevolution vs gevolution max of relative error: " +  str(np.max(file_kev-file_gev )) + " \n kevolution_old vs gevolution max of relative error: " + np.max(file_kev_old-file_gev ) + " \n kevolution_old vs kevolution max of relative error: " + np.max(file_kev_old-file_kev ) )
    max_kev_gev = np.max(np.abs(file_kev-file_gev )/file_gev)
    max_kev_old_gev = np.max(np.abs(file_kev_old-file_gev )/file_gev)
    max_kev_old_kev = np.max(np.abs(file_kev_old-file_kev )/file_kev)

    print("At z:"+ str(redshift) + " \n kevolution_old vs kevolution max of relative error: " + str(max_kev_old_kev)  + " at k=" + str(k[where(np.abs(file_kev_old-file_kev )/file_kev == max_kev_old_kev)]))
# Out:
# At z:100
#  kevolution_old vs kevolution max of relative error: 4.316112943349226 at k=[0.08458156]
# At z:50
#  kevolution_old vs kevolution max of relative error: 0.3589086947243095 at k=[0.04792972]
# At z:30
#  kevolution_old vs kevolution max of relative error: 0.3691606383671655 at k=[0.04527209]
# At z:20
#  kevolution_old vs kevolution max of relative error: 0.3827306215509652 at k=[0.04527209]
# At z:10
#  kevolution_old vs kevolution max of relative error: 0.3980503563548051 at k=[0.04527209]
# At z:9
#  kevolution_old vs kevolution max of relative error: 0.39922801818867154 at k=[0.04527209]
# At z:8
#  kevolution_old vs kevolution max of relative error: 0.40014369862928867 at k=[0.04527209]
# At z:7
#  kevolution_old vs kevolution max of relative error: 0.40064172565923967 at k=[0.04527209]
# At z:6
#  kevolution_old vs kevolution max of relative error: 0.4004254077636186 at k=[0.04527209]
# At z:5
#  kevolution_old vs kevolution max of relative error: 0.39896351626200705 at k=[0.04527209]
# At z:4
#  kevolution_old vs kevolution max of relative error: 0.39515025441206253 at k=[0.04527209]
# At z:3
#  kevolution_old vs kevolution max of relative error: 0.3863894879965858 at k=[0.04527209]
# At z:2.5
#  kevolution_old vs kevolution max of relative error: 0.3785865132106809 at k=[0.04527209]
# At z:2
#  kevolution_old vs kevolution max of relative error: 0.366786259910414 at k=[0.04527209]
# At z:1.5
#  kevolution_old vs kevolution max of relative error: 0.34937510078528233 at k=[0.04527209]
# At z:1
#  kevolution_old vs kevolution max of relative error: 0.3262256872014439 at k=[0.04527209]
# At z:0.9
#  kevolution_old vs kevolution max of relative error: 0.3215001393534001 at k=[0.04527209]
# At z:0.8
#  kevolution_old vs kevolution max of relative error: 0.31712632384939154 at k=[0.04527209]
# At z:0.7
#  kevolution_old vs kevolution max of relative error: 0.3134996710788111 at k=[0.04527209]
# At z:0.6
#  kevolution_old vs kevolution max of relative error: 0.3111700568882463 at k=[0.04527209]
# At z:0.5
#  kevolution_old vs kevolution max of relative error: 0.31083422402798033 at k=[0.04527209]
# At z:0.4
#  kevolution_old vs kevolution max of relative error: 0.3134797045206598 at k=[0.04527209]
# At z:0.3
#  kevolution_old vs kevolution max of relative error: 0.32092680586746175 at k=[0.04527209]
# At z:0.2
#  kevolution_old vs kevolution max of relative error: 0.33499663265938656 at k=[0.04527209]
# At z:0.1
#  kevolution_old vs kevolution max of relative error: 0.3585890746643068 at k=[0.04527209]
# At z:0.05
#  kevolution_old vs kevolution max of relative error: 0.3752556902232011 at k=[0.04527209]
# At z:0.01
#  kevolution_old vs kevolution max of relative error: 0.39145629121815295 at k=[0.04527209]
# At z:0
#  kevolution_old vs kevolution max of relative error: 0.3949401209880616 at k=[0.04527209]
