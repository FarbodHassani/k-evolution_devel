# %% [markdown]
# # k-evolution test notebook - implementing IC from class

# %%
import numpy as np
# import MAS_library as MASL
# import plotting_library as PL
from pylab import *
from matplotlib.colors import LogNorm
import matplotlib as plt
import pandas as pd
# import h5py as h5
import matplotlib.pyplot as plt
text_size=26
fig_size_x=24
fig_size_y=14
from collections import defaultdict

import seaborn as sns
Colors = sns.color_palette("colorblind", 30).as_hex()
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.interpolate import InterpolatedUnivariateSpline
from scipy import interpolate
import scipy.signal as sig
# from scipy.ndimage import gaussian_filter1

# %% [markdown]
# # Nested dictionary

# %%
def nested_dict(n, type):
    if n == 1:
        return defaultdict(type)
    else:
        return defaultdict(lambda: nested_dict(n-1, type))
    
data = nested_dict(5, list)

# %% [markdown]
# ## Background

# %%
As=2.215*1.e-9;
h=0.67556;
kp=0.05/h; 
ns=0.9619;
cs2_e3=1.e-7;
c=2.99792458*1.e5; #Km/s
# Boxsize=320.;
# c_gev=2997.92458; #[100km/s]
# H0_conf_Gev=np.sqrt(Boxsize**2/c**2); #0.10677 rho_crit in Gev=1
H0=100*h/c; #H0 in 1/Mpc unit. 0.00022593979933110373
# print("H0[1/Mpc]=100h/c: ",H0);
w=-0.9;
# print("H0[1/Mpc]=100h/c: ",H0);
def Hubble_conf_Mpc(a):
    c=2.99792458*1.e5;h=0.67556;H0=100*h/c;w=-0.9;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0;
    Omega_rad=9.1671353942930788e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_kessence*(a**(-3*(1+w))))*a

# %%
redshifts = [100, 50, 30,20, 10, 9, 8, 7, 6 , 5, 4, 3, 2.5, 2, 1.5, 1, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.05, 0.01, 0]

address_kev_old = "./unity_c_s2_em7_wm0d9/k_evolution_lightcone_project_using_IC_file/"
for i in range(np.shape(redshifts)[0]):
    data['kev_old']['bg'] = np.loadtxt(address_kev_old+"data__background.dat")
    data['kev_old']['pow_phi']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_phi.dat")
    data['kev_old']['pow_cdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_deltacdm.dat")
#     data['kev_old']['pow_ncdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_deltancdm.dat")
    data['kev_old']['pow_B']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_B.dat")
    data['kev_old']['pow_pk']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_pi_k.dat")
    data['kev_old']['pow_zeta']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_zeta.dat")
    data['kev_old']['pow_delta_kess']['z='+str(redshifts[i])] = np.loadtxt(address_kev_old+"data_pk_"+str(i).zfill(3)+"_delta_kess.dat")

data['kev_old']['bg'] = np.loadtxt(address_kev_old+"data__background.dat")


address_gev = "./unity_c_s2_em7_wm0d9//gevolution_devel/"

for i in range(np.shape(redshifts)[0]):
    data['gev']['pow_phi']['z='+str(redshifts[i])] = np.loadtxt(address_gev+"data_pk_"+str(i).zfill(3)+"_phi.dat")
    data['gev']['pow_cdm']['z='+str(redshifts[i])] = np.loadtxt(address_gev+"data_pk_"+str(i).zfill(3)+"_deltacdm.dat")
#     data['gev']['pow_ncdm']['z='+str(redshifts[i])] = np.loadtxt(address_gev+"data_pk_"+str(i).zfill(3)+"_deltancdm.dat")
    data['gev']['pow_B']['z='+str(redshifts[i])] = np.loadtxt(address_gev+"data_pk_"+str(i).zfill(3)+"_B.dat")
    data['gev']['pow_delta_kess']['z='+str(redshifts[i])] = np.loadtxt(address_gev+"data_pk_"+str(i).zfill(3)+"_deltaclass.dat")

data['gev']['bg'] = np.loadtxt(address_kev_old+"data__background.dat")

address_kev_dev = "./unity_c_s2_em7_wm0d9/k_evolution_devel//"

for i in range(np.shape(redshifts)[0]):
    data['kev']['pow_phi']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_phi.dat")
    data['kev']['pow_cdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_deltacdm.dat")
#     data['kev']['pow_ncdm']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_deltancdm.dat")
    data['kev']['pow_B']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_B.dat")
    data['kev']['pow_pk']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_pi_k.dat")
    data['kev']['pow_zeta']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_zeta.dat")
    data['kev']['pow_delta_kess']['z='+str(redshifts[i])] = np.loadtxt(address_kev_dev+"data_pk_"+str(i).zfill(3)+"_delta_kess.dat")

data['kev']['bg'] = np.loadtxt(address_kev_old+"data__background.dat")


address_class = "./unity_c_s2_em7_wm0d9/class_v2.7.1/"

for i in range(np.shape(redshifts)[0]):
    data['class']['tk']['z='+str(redshifts[i])] = np.loadtxt(address_class+"data_class_z"+str(i+1)+"_tk.dat")

data['class']['bg'] = np.loadtxt(address_class+"data_class_background.dat")

# %% [markdown]
# # Background test

# %%
plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,10),nrows=2, ncols=1)
plt.subplots_adjust(hspace=0.09)
l=0
file_gev = data['gev']['bg']
f_gev = interpolate.interp1d(file_gev[:,2],file_gev[:,3])
axs[0].loglog(file_gev[:,2],file_gev[:,3],"-",color =Colors[l], lw=3,label="gevolution")

file = data['kev']['bg']
axs[0].loglog(file[:,2],file[:,3],"-",color =Colors[l+1], lw=3,label="kevolution")

file = data['kev_old']['bg']
axs[0].loglog(file[:,2],file[:,3],"-",color =Colors[l+3], lw=3,label="kevolution old")

file_class = data['class']['bg']
z = file_class[:,0]
a = 1./(1. + z )
f_class = interpolate.interp1d(a, file_class[:,3])

axs[0].loglog(a,file_class[:,3]*a*f_gev(1)/f_class(1),"-",color =Colors[l+2], lw=3,label="CLASS")

axs[0].set_ylabel(r'$\mathcal{H}$',fontsize=24)
axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_ylim(0.8,1.e1)
axs[0].set_xlim(1.e-2,2.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=20,bbox_to_anchor=[0.75,0.82],loc="center",frameon=False)



l=0
file_gev = data['gev']['bg']
# axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

file = data['kev']['bg']
axs[1].plot(file[:,2],np.abs(file[:,3]-file_gev[:,3])/file_gev[:,3],"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

file = data['kev_old']['bg']
axs[1].plot(file[:,2],np.abs(file[:,3]-file_gev[:,3])/file_gev[:,3],"-",color =Colors[l+2], lw=3,label="kevolution old vs gevolution")

file = data['kev_old']['bg']
num = np.shape(file_gev[:100,2])[0]-1
a  = file_gev[:num,2]
file_class = f_class(a)*a*f_gev(1)/f_class(1)
axs[1].plot(a,np.abs(file_class-file_gev[:num,3])/file_gev[:num,3],"-",color =Colors[l+3], lw=3,label="class vs gevolution")

axs[1].set_ylabel(r'$P_{l}(k)$',fontsize=24)
axs[1].set_xlabel('$a$',fontsize=24)
axs[1].set_xscale('log')
# axs[1].set_yscale('log')
axs[1].set_ylim(-0.01,0.01)
axs[1].set_xlim(1.e-2,2.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.75,0.82],loc="center",frameon=False)
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## Numerical background comparison

# %%
file1 = data['kev']['bg']
file2 = data['gev']['bg']
file3 = data['kev_old']['bg']
print(np.sum(file1-file2),np.sum( file1-file3), np.sum(file2 -file3)  )
if (np.sum(file1-file2)!=0 or np.sum( file1-file3)!= 0 or  np.sum(file2 -file3) !=0 ):
    print("\x1b[31m\"ERROR - Something is wrong! There is an inconsistency in the BG file\"\x1b[0m")
# Out:
# 0.0 0.0 0.0

# %% [markdown]
# # Matter power spectrum CHECK

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,20),nrows=2, ncols=1)
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_cdm'

Normlization=As*(data['class']['tk']['z='+str(100)][:,0]/kp)**(ns-1.);

for redshift in [100, 1 ,0]:
    file = data['gev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+1], lw=3,label="kevolution")

    file = data['kev_old'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+2], lw=3,label="kevolution old")
    
    file = data['class']['tk']['z='+str(redshift)]
    delta_cdm = file[:,3]
    k = file[:,0]
    power = delta_cdm**2 * (Normlization)
    axs[0].loglog(k,power,":",color =Colors[l+2], lw=3,label="CLASS")
    l=l+3

axs[0].set_ylabel(r'$P$',fontsize=24)
axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
# axs[0].set_ylim(0.8,1.e1)
axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=20,bbox_to_anchor=[0.75,0.82],loc="center",frameon=False)


l=0
for redshift in [100,6,1,0]:
#     print(redshift)
    k = data['gev'][kind]['z='+str(redshift)] [:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution"+ 'z='+str(redshift))

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev_old-file_gev)/file_gev,"-",color =Colors[l+2], lw=3,label="kevolution old vs gevolution"+ 'z='+str(redshift))
    l=l+2

axs[1].set_ylabel(r'$\Delta P(k)$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
# axs[1].set_yscale('log')
axs[1].set_ylim(-0.04,0.04)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.65,0.22],loc="center",frameon=False)

# %% [markdown]
# ## Numerical test

# %%
kind = 'pow_cdm'
for redshift in redshifts:

    k = data['gev'][kind]['z='+str(redshift)] [:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    
#     print("At z:"+ str(redshifts[i]) + "\n kevolution vs gevolution max of relative error: " +  str(np.max(file_kev-file_gev )) + " \n kevolution_old vs gevolution max of relative error: " + np.max(file_kev_old-file_gev ) + " \n kevolution_old vs kevolution max of relative error: " + np.max(file_kev_old-file_kev ) )
    max_kev_gev = np.max(np.abs(file_kev-file_gev )/file_gev)
    max_kev_old_gev = np.max(np.abs(file_kev_old-file_gev )/file_gev)
    max_kev_old_kev = np.max(np.abs(file_kev_old-file_kev )/file_kev)

    print("At z:"+ str(redshift) + "\n kevolution vs gevolution max of relative error: " +  str(max_kev_gev) + " at k=" + str(k[where(np.abs(file_kev-file_gev )/file_gev == max_kev_gev)])
         + " \n kevolution_old vs gevolution max of relative error: " + str(max_kev_old_gev)   + " at k=" + str(k[where(np.abs(file_kev_old-file_gev )/file_gev == max_kev_old_gev)])
          + " \n kevolution_old vs kevolution max of relative error: " + str(max_kev_old_kev)  + " at k=" + str(k[where(np.abs(file_kev_old-file_kev )/file_kev == max_kev_old_kev)]))
# Out:
# At z:100
#  kevolution vs gevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
#  kevolution_old vs gevolution max of relative error: 0.0016842607244270797 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0016842607244270797 at k=[0.00155833]
# At z:50
#  kevolution vs gevolution max of relative error: 8.638995389108605e-07 at k=[0.02835132]
#  kevolution_old vs gevolution max of relative error: 0.000780461324786503 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.000780461324786503 at k=[0.00155833]
# At z:30
#  kevolution vs gevolution max of relative error: 9.79797554339059e-07 at k=[0.05033911]
#  kevolution_old vs gevolution max of relative error: 0.0006631129144847077 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006632868470531928 at k=[0.00155833]
# At z:20
#  kevolution vs gevolution max of relative error: 1.425182548081852e-06 at k=[0.07265895]
#  kevolution_old vs gevolution max of relative error: 0.0006366851787871225 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006370451848763292 at k=[0.00155833]
# At z:10
#  kevolution vs gevolution max of relative error: 1.1668806247019404e-05 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0006235364291080693 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006240890646894398 at k=[0.00155833]
# At z:9
#  kevolution vs gevolution max of relative error: 1.715913380700926e-05 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0006220885022637982 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006230580912038777 at k=[0.00155833]
# At z:8
#  kevolution vs gevolution max of relative error: 2.5824252019996457e-05 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0006210095123946499 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006214276788986115 at k=[0.00155833]
# At z:7
#  kevolution vs gevolution max of relative error: 4.1089144825795825e-05 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0006199451137230167 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006206500340442341 at k=[0.00155833]
# At z:6
#  kevolution vs gevolution max of relative error: 6.865070088885619e-05 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0006186171788291043 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006191937975740897 at k=[0.00155833]
# At z:5
#  kevolution vs gevolution max of relative error: 0.00012478180419322134 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0006173868302012549 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006182956474984724 at k=[0.00155833]
# At z:4
#  kevolution vs gevolution max of relative error: 0.0002478891024665913 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.000615448382940291 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.000616978179493039 at k=[0.00155833]
# At z:3
#  kevolution vs gevolution max of relative error: 0.0005660545191366845 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0008372841970649512 at k=[0.08375931]
#  kevolution_old vs kevolution max of relative error: 0.0006153096096640668 at k=[0.00155833]
# At z:2.5
#  kevolution vs gevolution max of relative error: 0.0009020681808742298 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.0011091002223863758 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 0.0006149574245733203 at k=[0.00155833]
# At z:2
#  kevolution vs gevolution max of relative error: 0.001490081316414585 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.001706685216724017 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 0.0006132386721998967 at k=[0.00155833]
# At z:1.5
#  kevolution vs gevolution max of relative error: 0.0024611056148084675 at k=[0.08133227]
#  kevolution_old vs gevolution max of relative error: 0.002702245042793661 at k=[0.08133227]
#  kevolution_old vs kevolution max of relative error: 0.0006130031891208271 at k=[0.00155833]
# At z:1
#  kevolution vs gevolution max of relative error: 0.004281426676903763 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.0044697370757892435 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0006126341773571825 at k=[0.00155833]
# At z:0.9
#  kevolution vs gevolution max of relative error: 0.005012856963310923 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.005175479715889929 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.0006130888609891893 at k=[0.00155833]
# At z:0.8
#  kevolution vs gevolution max of relative error: 0.00588813358033778 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.006044702032838415 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.0006135140499473183 at k=[0.00155833]
# At z:0.7
#  kevolution vs gevolution max of relative error: 0.006928876255160548 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.007079244323166396 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.0006142643704271212 at k=[0.00155833]
# At z:0.6
#  kevolution vs gevolution max of relative error: 0.008253765267445671 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.00839691621057188 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.0006151153095424567 at k=[0.00155833]
# At z:0.5
#  kevolution vs gevolution max of relative error: 0.009844716790401387 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.009979595622333394 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.0006161556296741059 at k=[0.00155833]
# At z:0.4
#  kevolution vs gevolution max of relative error: 0.011823019628002165 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.011948810228409818 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.0006177939627421997 at k=[0.00155833]
# At z:0.3
#  kevolution vs gevolution max of relative error: 0.014308186008518615 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.014423478616021966 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.000619766853600469 at k=[0.00155833]
# At z:0.2
#  kevolution vs gevolution max of relative error: 0.01739376980842352 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.017497785986294503 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.0006221239611285796 at k=[0.00155833]
# At z:0.1
#  kevolution vs gevolution max of relative error: 0.021237117632586636 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.021328225281356153 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.0006250149461864022 at k=[0.00155833]
# At z:0.05
#  kevolution vs gevolution max of relative error: 0.023509942276175685 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.023594274401402205 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.0006269272917251385 at k=[0.00155833]
# At z:0.01
#  kevolution vs gevolution max of relative error: 0.0255257682473413 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.02560446086424966 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 0.0006279853004922435 at k=[0.00155833]
# At z:0
#  kevolution vs gevolution max of relative error: 0.02634133185894234 at k=[0.07710189]
#  kevolution_old vs gevolution max of relative error: 0.02631040885283412 at k=[0.07710189]
#  kevolution_old vs kevolution max of relative error: 5.220441339095888e-05 at k=[0.08375931]

# %% [markdown]
# # Potential power spectrum

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,20),nrows=2, ncols=1,gridspec_kw={'height_ratios': [1, 2]})
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_phi'
Normlization=As*(data['class']['tk']['z='+str(100)][:,0]/kp)**(ns-1.);

for redshift in [100, 1 ,0]:
    file = data['gev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+1], lw=3,label="kevolution" + 'z='+str(redshift))

    file = data['kev_old'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+2], lw=3,label="kevolution old" + 'z='+str(redshift))
    
    file = data['class']['tk']['z='+str(redshift)]
    delta = file[:,9]
    k = file[:,0]
    power = delta**2 * (Normlization)
    axs[0].loglog(k,power,":",color =Colors[l+2], lw=3,label="CLASS")
    l=l+3

axs[0].set_ylabel(r'$P_{\Phi}$',fontsize=24)
# axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_ylim(1.e-14,1.e-8)
axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=18,bbox_to_anchor=[0.25,0.22],ncol=2,loc="center",frameon=False)


l=0
for redshift in [100, 6,1, 0.5,0.01,0]:
#     print(redshift)
    k = data['gev'][kind]['z='+str(redshift)] [:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kev-gev"+ ', z='+str(redshift))

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev_old-file_kev)/file_kev,"o",markersize=10,color =Colors[l+2], lw=3,label="kev-old vs kev"+ ', z='+str(redshift))
    l=l+3

axs[1].set_ylabel(r'$\Delta$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
# axs[1].set_yscale('log')
axs[1].set_ylim(-0.01,0.2)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.5,0.82],ncol=3,loc="center",frameon=False)
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## Numerical test

# %%
kind = 'pow_phi'
for redshift in redshifts:

    k = data['gev'][kind]['z='+str(redshift)] [:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    
#     print("At z:"+ str(redshifts[i]) + "\n kevolution vs gevolution max of relative error: " +  str(np.max(file_kev-file_gev )) + " \n kevolution_old vs gevolution max of relative error: " + np.max(file_kev_old-file_gev ) + " \n kevolution_old vs kevolution max of relative error: " + np.max(file_kev_old-file_kev ) )
    max_kev_gev = np.max(np.abs(file_kev-file_gev )/file_gev)
    max_kev_old_gev = np.max(np.abs(file_kev_old-file_gev )/file_gev)
    max_kev_old_kev = np.max(np.abs(file_kev_old-file_kev )/file_kev)

    print("At z:"+ str(redshift) + "\n kevolution vs gevolution max of relative error: " +  str(max_kev_gev) + " at k=" + str(k[where(np.abs(file_kev-file_gev )/file_gev == max_kev_gev)])
         + " \n kevolution_old vs gevolution max of relative error: " + str(max_kev_old_gev)   + " at k=" + str(k[where(np.abs(file_kev_old-file_gev )/file_gev == max_kev_old_gev)])
          + " \n kevolution_old vs kevolution max of relative error: " + str(max_kev_old_kev)  + " at k=" + str(k[where(np.abs(file_kev_old-file_kev )/file_kev == max_kev_old_kev)]))
# Out:
# At z:100
#  kevolution vs gevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
#  kevolution_old vs gevolution max of relative error: 2.748657201846198 at k=[0.073374]
#  kevolution_old vs kevolution max of relative error: 2.748657201846198 at k=[0.073374]
# At z:50
#  kevolution vs gevolution max of relative error: 1.8759332767926277e-06 at k=[0.08192725]
#  kevolution_old vs gevolution max of relative error: 0.0005813320498764855 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0005811310582111193 at k=[0.00155833]
# At z:30
#  kevolution vs gevolution max of relative error: 8.416875836110614e-06 at k=[0.08200132]
#  kevolution_old vs gevolution max of relative error: 0.0006385702538185403 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006383666279753402 at k=[0.00155833]
# At z:20
#  kevolution vs gevolution max of relative error: 2.8362640117216706e-05 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0006381751757031188 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006377649076778643 at k=[0.00155833]
# At z:10
#  kevolution vs gevolution max of relative error: 0.0003414106262760023 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.000626383461656776 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006251419132113559 at k=[0.00155833]
# At z:9
#  kevolution vs gevolution max of relative error: 0.00048642976848775 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0006252140115842753 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.0006235567827947135 at k=[0.00155833]
# At z:8
#  kevolution vs gevolution max of relative error: 0.0007147090432978038 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0008291933294096029 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0006224643077970564 at k=[0.00155833]
# At z:7
#  kevolution vs gevolution max of relative error: 0.0010952397557052588 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0012096782686412252 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0006208923745033731 at k=[0.00155833]
# At z:6
#  kevolution vs gevolution max of relative error: 0.0017716801105869973 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0018848298868093627 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0006211788914046614 at k=[0.00155833]
# At z:5
#  kevolution vs gevolution max of relative error: 0.0030603778723338067 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0031715225290544088 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0006214939227995424 at k=[0.00155833]
# At z:4
#  kevolution vs gevolution max of relative error: 0.005785725667862427 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.005893157172290956 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.000623327845505211 at k=[0.00155833]
# At z:3
#  kevolution vs gevolution max of relative error: 0.012444795324152543 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.012543608238027585 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0006291437474058212 at k=[0.00155833]
# At z:2.5
#  kevolution vs gevolution max of relative error: 0.019464371567357433 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.019554369270047594 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0006351913016054896 at k=[0.00155833]
# At z:2
#  kevolution vs gevolution max of relative error: 0.03227896652125845 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.03235351700621979 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.000645331694669543 at k=[0.00155833]
# At z:1.5
#  kevolution vs gevolution max of relative error: 0.057437140918646615 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.05748309664740424 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0006633561322964865 at k=[0.00155833]
# At z:1
#  kevolution vs gevolution max of relative error: 0.11091556637578033 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.11090895517135525 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0006943314147899996 at k=[0.00155833]
# At z:0.9
#  kevolution vs gevolution max of relative error: 0.12792084143847945 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.1279004220777091 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0007027608562203302 at k=[0.00155833]
# At z:0.8
#  kevolution vs gevolution max of relative error: 0.14793645661142255 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.14790115228482778 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0007121901113884126 at k=[0.00155833]
# At z:0.7
#  kevolution vs gevolution max of relative error: 0.17143130914593224 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.1713807152154451 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0007219617082710162 at k=[0.00155833]
# At z:0.6
#  kevolution vs gevolution max of relative error: 0.1993918264551942 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.19932603958925804 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0007330969459640058 at k=[0.00155833]
# At z:0.5
#  kevolution vs gevolution max of relative error: 0.23209176936283404 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.23201193611041385 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0007445420509246221 at k=[0.00155833]
# At z:0.4
#  kevolution vs gevolution max of relative error: 0.2704397317924381 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.2703481555950038 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0007566308399176645 at k=[0.00155833]
# At z:0.3
#  kevolution vs gevolution max of relative error: 0.31511949118388694 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.3150205392763155 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0007688394837326161 at k=[0.00155833]
# At z:0.2
#  kevolution vs gevolution max of relative error: 0.36643801569433937 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.36633768395947697 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0007801461326129775 at k=[0.00155833]
# At z:0.1
#  kevolution vs gevolution max of relative error: 0.42450652345308093 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.4244131427035159 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0007912804375259788 at k=[0.00155833]
# At z:0.05
#  kevolution vs gevolution max of relative error: 0.4559924263914356 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.4559060409018907 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.000795203757027999 at k=[0.00155833]
# At z:0.01
#  kevolution vs gevolution max of relative error: 0.48010579962786054 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.4800272654042454 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0007985755551820214 at k=[0.00155833]
# At z:0
#  kevolution vs gevolution max of relative error: 0.126481505116536 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.12650569057647057 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.00016443472438277247 at k=[0.00155833]

# %% [markdown]
# # B power spectrum

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,20),nrows=2, ncols=1,gridspec_kw={'height_ratios': [1, 3]})
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_B'
for redshift in [100, 1 ,0]:
    file = data['gev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"o",color =Colors[l+1], lw=3,label="kevolution")

    file = data['kev_old'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+2], lw=3,label="kevolution old")
    l=l+3

axs[0].set_ylabel(r'$P_{\Phi}$',fontsize=24)
# axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
# axs[0].set_ylim(0.8,1.e1)
axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=18,bbox_to_anchor=[0.95,0.82],loc="center",frameon=False)


l=0
for redshift in [100, 6,1, 0.5,0.01,0]:
#     print(redshift)
    k = data['gev'][kind]['z='+str(redshift)] [:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kev-gev"+ ', z='+str(redshift))

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(file[:,2],np.abs(file_kev_old-file_kev)/file_kev,"o",markersize=10,color =Colors[l+2], lw=3,label="kev-old vs kev"+ ', z='+str(redshift))
    l=l+3

axs[1].set_ylabel(r'$\Delta$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
# axs[1].set_yscale('log')
axs[1].set_ylim(-0.01,0.2)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.5,0.82],ncol=3,loc="center",frameon=False)

# %% [markdown]
# # delta kess

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,20),nrows=2, ncols=1,gridspec_kw={'height_ratios': [1, 2]})
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_delta_kess'
Normlization=As*(data['class']['tk']['z='+str(100)][:,0]/kp)**(ns-1.);

for redshift in [100,1,0]:
#     file = data['gev'][kind]['z='+str(redshift)] 
#     k = file[:,0]
#     axs[0].loglog(k,file[:,1],"-",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"o",color =Colors[l+1], lw=3,label="kevolution")

    file = data['kev_old'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-.",color =Colors[l+2], lw=3,label="kevolution old")
    
    file = data['class']['tk']['z='+str(redshift)]
    delta = file[:,4]
    k = file[:,0]
    power = delta**2 * (Normlization)
    axs[0].loglog(k,power,":",color =Colors[l+2], lw=3,label="CLASS")
    
    l=l+3

axs[0].set_ylabel(r'$P_{\Delta_kess}$',fontsize=24)
# axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_ylim(1.e-11,1.e-4)
axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=20,bbox_to_anchor=[0.75,0.32],loc="center",frameon=False)


l=0
for redshift in [100,1,0]:
#     print(redshift)
    k = data['gev'][kind]['z='+str(redshift)][:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)][:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")
    
    
    
    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kev-gev"+ ', z='+str(redshift))

    
    file = data['class']['tk']['z='+str(redshift)]
    delta = file[:,4]
    k_class = file[:,0]
    power = delta**2 * (Normlization)
    f_kess_class = interpolate.interp1d(k_class, power)
    file_class = f_kess_class(k)
    axs[1].plot(k,np.abs(file_class-file_kev)/file_kev,":",color =Colors[l+3], lw=3,label="class-kev"+ ', z='+str(redshift))


    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev_old-file_kev)/file_kev,"o",markersize=10,color =Colors[l+2], lw=3,label="kev-old vs kev"+ ', z='+str(redshift))
    l=l+3

axs[1].set_ylabel(r'$\Delta$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[1].set_ylim(1.e-4,1)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.5,0.82],ncol=3,loc="center",frameon=False)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:52: RuntimeWarning: divide by zero encountered in true_divide

# %% [markdown]
# ## Numerical test:

# %%
kind = 'pow_B'
for redshift in redshifts:

    k = data['kev'][kind]['z='+str(redshift)] [:,0]
    file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
#     axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    
    
    file = data['class']['tk']['z='+str(redshift)]
    delta = file[:,4]
    k_class = file[:,0]
    power = delta**2 * (Normlization)
    f_kess_class = interpolate.interp1d(k_class, power)
    file_class = f_kess_class(k)

#     print("At z:"+ str(redshifts[i]) + "\n kevolution vs gevolution max of relative error: " +  str(np.max(file_kev-file_gev )) + " \n kevolution_old vs gevolution max of relative error: " + np.max(file_kev_old-file_gev ) + " \n kevolution_old vs kevolution max of relative error: " + np.max(file_kev_old-file_kev ) )
    max_kev_gev = np.max(np.abs(file_kev-file_gev )/file_gev)
    max_kev_old_gev = np.max(np.abs(file_kev_old-file_gev )/file_gev)
    max_kev_old_kev = np.max(np.abs(file_kev_old-file_kev )/file_kev)
    max_class_kev = np.max(np.abs(file_class-file_kev )/file_kev)

    

    print("At z:"+ str(redshift) + "\n kevolution vs gevolution max of relative error: " +  str(max_kev_gev) + " at k=" + str(k[where(np.abs(file_kev-file_gev )/file_gev == max_kev_gev)])
         + " \n kevolution_old vs gevolution max of relative error: " + str(max_kev_old_gev)   + " at k=" + str(k[where(np.abs(file_kev_old-file_gev )/file_gev == max_kev_old_gev)])
#          + " \n class vs kevolution max of relative error: " + str(max_class_kev)   + " at k=" + str(k[where(np.abs(file_class-file_kev )/file_kev == max_class_kev)])
          + " \n kevolution_old vs kevolution max of relative error: " + str(max_kev_old_kev)  + " at k=" + str(k[where(np.abs(file_kev_old-file_kev )/file_kev == max_kev_old_kev)]))
# Out:
# At z:100
#  kevolution vs gevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
#  kevolution_old vs gevolution max of relative error: 0.00030034057358201523 at k=[0.00155833]
#  kevolution_old vs kevolution max of relative error: 0.00030034057358201523 at k=[0.00155833]
# At z:50
#  kevolution vs gevolution max of relative error: 9.864549866201594e-07 at k=[0.0764782]
#  kevolution_old vs gevolution max of relative error: 0.0002884413557973234 at k=[0.00220381]
#  kevolution_old vs kevolution max of relative error: 0.0002882136332333061 at k=[0.00220381]
# At z:30
#  kevolution vs gevolution max of relative error: 1.4734104663384365e-06 at k=[0.0449491]
#  kevolution_old vs gevolution max of relative error: 0.0003316258058766276 at k=[0.00220381]
#  kevolution_old vs kevolution max of relative error: 0.0003316258058766276 at k=[0.00220381]
# At z:20
#  kevolution vs gevolution max of relative error: 5.851228611749822e-06 at k=[0.08548117]
#  kevolution_old vs gevolution max of relative error: 0.00033689248960213394 at k=[0.00220381]
#  kevolution_old vs kevolution max of relative error: 0.00033689248960213394 at k=[0.00220381]
# At z:10
#  kevolution vs gevolution max of relative error: 6.849403584948291e-05 at k=[0.08548117]
#  kevolution_old vs gevolution max of relative error: 0.00033789944295851585 at k=[0.00381711]
#  kevolution_old vs kevolution max of relative error: 0.00033789944295851585 at k=[0.00381711]
# At z:9
#  kevolution vs gevolution max of relative error: 8.863426288920826e-05 at k=[0.08548117]
#  kevolution_old vs gevolution max of relative error: 0.00034587212772723753 at k=[0.07942897]
#  kevolution_old vs kevolution max of relative error: 0.0003387358850597072 at k=[0.00381711]
# At z:8
#  kevolution vs gevolution max of relative error: 0.00012550175802065257 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.00037712262727015956 at k=[0.07942897]
#  kevolution_old vs kevolution max of relative error: 0.0003385614805526129 at k=[0.00381711]
# At z:7
#  kevolution vs gevolution max of relative error: 0.0001937859970237888 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0004296668643112317 at k=[0.07942897]
#  kevolution_old vs kevolution max of relative error: 0.0003388725558895455 at k=[0.00381711]
# At z:6
#  kevolution vs gevolution max of relative error: 0.000314687906415714 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0005225323779668181 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.00033843186999619356 at k=[0.00381711]
# At z:5
#  kevolution vs gevolution max of relative error: 0.0005441812996646747 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0007229879184516549 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0003381045032001577 at k=[0.00381711]
# At z:4
#  kevolution vs gevolution max of relative error: 0.0010281221160159872 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0011501790165658104 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0003401387449670352 at k=[0.00220381]
# At z:3
#  kevolution vs gevolution max of relative error: 0.0021864298860147925 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0022987180855883202 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.000351325003101185 at k=[0.08548117]
# At z:2.5
#  kevolution vs gevolution max of relative error: 0.0033812055547821932 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0034921193010437317 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.0003588817941215267 at k=[0.08548117]
# At z:2
#  kevolution vs gevolution max of relative error: 0.005490967298994973 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.0055993514888064005 at k=[0.04527209]
#  kevolution_old vs kevolution max of relative error: 0.00036324372871577947 at k=[0.08548117]
# At z:1.5
#  kevolution vs gevolution max of relative error: 0.009439251207031383 at k=[0.04527209]
#  kevolution_old vs gevolution max of relative error: 0.009637831082388195 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0003724197504706154 at k=[0.00220381]
# At z:1
#  kevolution vs gevolution max of relative error: 0.01858191345547714 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.01880356501996162 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0003942749062347356 at k=[0.00220381]
# At z:0.9
#  kevolution vs gevolution max of relative error: 0.021543223735056814 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.021760579190698664 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.00040087110971570144 at k=[0.00220381]
# At z:0.8
#  kevolution vs gevolution max of relative error: 0.025058271824777725 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.02527082900287208 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0004073949405015521 at k=[0.00220381]
# At z:0.7
#  kevolution vs gevolution max of relative error: 0.02923423086822597 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.02944134011212504 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0004149867236529164 at k=[0.00220381]
# At z:0.6
#  kevolution vs gevolution max of relative error: 0.03420352111756777 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.0344043491314691 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0004231963182995298 at k=[0.00220381]
# At z:0.5
#  kevolution vs gevolution max of relative error: 0.04009755215932771 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.04029095934371584 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0004321217466080399 at k=[0.00220381]
# At z:0.4
#  kevolution vs gevolution max of relative error: 0.04705934802005321 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.04724439262923957 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.00044271569858891186 at k=[0.00220381]
# At z:0.3
#  kevolution vs gevolution max of relative error: 0.055205971989179176 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.05538266616443527 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0004538767921928435 at k=[0.00220381]
# At z:0.2
#  kevolution vs gevolution max of relative error: 0.06465864799191635 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.06482614735113391 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.00046589378799118065 at k=[0.00220381]
# At z:0.1
#  kevolution vs gevolution max of relative error: 0.07548861572933573 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.07564827785901208 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0004781797069560418 at k=[0.00220381]
# At z:0.05
#  kevolution vs gevolution max of relative error: 0.08141302678093576 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.08156791414758635 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.00048508198712923295 at k=[0.00220381]
# At z:0.01
#  kevolution vs gevolution max of relative error: 0.086385914507309 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.08653768698327098 at k=[0.0805673]
#  kevolution_old vs kevolution max of relative error: 0.0004899013819019091 at k=[0.00220381]
# At z:0
#  kevolution vs gevolution max of relative error: 0.0958196526421834 at k=[0.0805673]
#  kevolution_old vs gevolution max of relative error: 0.09574615356015688 at k=[0.08458156]
#  kevolution_old vs kevolution max of relative error: 0.0001481340353215511 at k=[0.00220381]

# %% [markdown]
# # pi_k power spectrum

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,20),nrows=2, ncols=1,gridspec_kw={'height_ratios': [1, 3]})
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_pk'
for redshift in [100, 1 ,0]:
#     file = data['gev'][kind]['z='+str(redshift)] 
#     axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"o",color =Colors[l+1], lw=3,label="kevolution")

    file = data['kev_old'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+2], lw=3,label="kevolution old")
    l=l+3

axs[0].set_ylabel(r'$P_{\pi_k}$',fontsize=24)
# axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_ylim(1.e-12,1.e-9)
axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=18,bbox_to_anchor=[0.95,0.82],loc="center",frameon=False)


l=0
for redshift in [100, 6,1, 0.5,0.01,0]:
#     print(redshift)
    k = data['kev'][kind]['z='+str(redshift)] [:,0]
#     file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
#     # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
#     axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kev-gev"+ ', z='+str(redshift))

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev_old-file_kev)/file_kev,"o",markersize=10,color =Colors[l+2], lw=3,label="kev-old vs kev"+ ', z='+str(redshift))
    l=l+3

axs[1].set_ylabel(r'$\Delta$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[1].set_ylim(1.e-5,0.04)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.5,0.82],ncol=3,loc="center",frameon=False)

# %% [markdown]
# ## numerical check

# %%
kind = 'pow_pk'
for redshift in redshifts:

#     k = data['gev'][kind]['z='+str(redshift)] [:,0]
#     file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    
#     print("At z:"+ str(redshifts[i]) + "\n kevolution vs gevolution max of relative error: " +  str(np.max(file_kev-file_gev )) + " \n kevolution_old vs gevolution max of relative error: " + np.max(file_kev_old-file_gev ) + " \n kevolution_old vs kevolution max of relative error: " + np.max(file_kev_old-file_kev ) )
    max_kev_gev = np.max(np.abs(file_kev-file_gev )/file_gev)
    max_kev_old_gev = np.max(np.abs(file_kev_old-file_gev )/file_gev)
    max_kev_old_kev = np.max(np.abs(file_kev_old-file_kev )/file_kev)

    print("At z:"+ str(redshift) + " \n kevolution_old vs kevolution max of relative error: " + str(max_kev_old_kev)  + " at k=" + str(k[where(np.abs(file_kev_old-file_kev )/file_kev == max_kev_old_kev)]))
# Out:
# At z:100
#  kevolution_old vs kevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
# At z:50
#  kevolution_old vs kevolution max of relative error: 0.00031724686273393825 at k=[0.07460478]
# At z:30
#  kevolution_old vs kevolution max of relative error: 0.00046194195133117643 at k=[0.00155833]
# At z:20
#  kevolution_old vs kevolution max of relative error: 0.0005415991614792938 at k=[0.00155833]
# At z:10
#  kevolution_old vs kevolution max of relative error: 0.0005968030336014743 at k=[0.00155833]
# At z:9
#  kevolution_old vs kevolution max of relative error: 0.0006006307552698436 at k=[0.00155833]
# At z:8
#  kevolution_old vs kevolution max of relative error: 0.0006038944689769091 at k=[0.00155833]
# At z:7
#  kevolution_old vs kevolution max of relative error: 0.000606508058854113 at k=[0.00155833]
# At z:6
#  kevolution_old vs kevolution max of relative error: 0.0006088068497719739 at k=[0.00155833]
# At z:5
#  kevolution_old vs kevolution max of relative error: 0.0006113938300518656 at k=[0.00155833]
# At z:4
#  kevolution_old vs kevolution max of relative error: 0.0006138893500083554 at k=[0.00155833]
# At z:3
#  kevolution_old vs kevolution max of relative error: 0.000616867224334071 at k=[0.00155833]
# At z:2.5
#  kevolution_old vs kevolution max of relative error: 0.0006191660486263316 at k=[0.00155833]
# At z:2
#  kevolution_old vs kevolution max of relative error: 0.0006228733986575791 at k=[0.00155833]
# At z:1.5
#  kevolution_old vs kevolution max of relative error: 0.0006296858657857234 at k=[0.00155833]
# At z:1
#  kevolution_old vs kevolution max of relative error: 0.0006423586891988994 at k=[0.00155833]
# At z:0.9
#  kevolution_old vs kevolution max of relative error: 0.0006460535335661905 at k=[0.00155833]
# At z:0.8
#  kevolution_old vs kevolution max of relative error: 0.0006500614511215537 at k=[0.00155833]
# At z:0.7
#  kevolution_old vs kevolution max of relative error: 0.0006547770856273706 at k=[0.00155833]
# At z:0.6
#  kevolution_old vs kevolution max of relative error: 0.0006598999671907976 at k=[0.00155833]
# At z:0.5
#  kevolution_old vs kevolution max of relative error: 0.0006658842196964309 at k=[0.00155833]
# At z:0.4
#  kevolution_old vs kevolution max of relative error: 0.0006725769175213671 at k=[0.00155833]
# At z:0.3
#  kevolution_old vs kevolution max of relative error: 0.0006797574034664117 at k=[0.00155833]
# At z:0.2
#  kevolution_old vs kevolution max of relative error: 0.0006878221593372727 at k=[0.00155833]
# At z:0.1
#  kevolution_old vs kevolution max of relative error: 0.0006963098866132644 at k=[0.00155833]
# At z:0.05
#  kevolution_old vs kevolution max of relative error: 0.0007006352078175814 at k=[0.00155833]
# At z:0.01
#  kevolution_old vs kevolution max of relative error: 0.0007036668516787855 at k=[0.00155833]
# At z:0
#  kevolution_old vs kevolution max of relative error: 0.00011833966467116699 at k=[0.04527209]

# %% [markdown]
# # zeta power

# %%
# plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : text_size}
matplotlib.rc('font', **font)
fig, axs = plt.subplots(figsize=(15,20),nrows=2, ncols=1,gridspec_kw={'height_ratios': [1, 3]})
plt.subplots_adjust(hspace=0.09)
l=0
kind = 'pow_zeta'
for redshift in [100, 1 ,0]:
#     file = data['gev'][kind]['z='+str(redshift)] 
#     axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l], lw=3,label="gevolution" + 'z='+str(redshift))

    file = data['kev'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"o",color =Colors[l+1], lw=3,label="kevolution")

    file = data['kev_old'][kind]['z='+str(redshift)] 
    axs[0].loglog(file[:,0],file[:,1],"-",color =Colors[l+2], lw=3,label="kevolution old")
    l=l+3

axs[0].set_ylabel(r'$P_{\zeta}$',fontsize=24)
# axs[0].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
# axs[0].set_ylim(1.e-12,1.e-9)
axs[0].set_xlim(1.e-3,1.e-1)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
axs[0].set_title("Background comparison", fontsize=22)
axs[0].legend(fontsize=18,bbox_to_anchor=[0.95,0.82],loc="center",frameon=False)


l=0
for redshift in [100, 6,1, 0.5,0.01,0]:
#     print(redshift)
    k = data['kev'][kind]['z='+str(redshift)] [:,0]
#     file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
#     # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
#     axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kev-gev"+ ', z='+str(redshift))

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev_old-file_kev)/file_kev,"o",markersize=10,color =Colors[l+2], lw=3,label="kev-old vs kev"+ ', z='+str(redshift))
    l=l+3

axs[1].set_ylabel(r'$\Delta$',fontsize=24)
axs[1].set_xlabel('$k$[h/Mpc]',fontsize=24)
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[1].set_ylim(1.e-5,0.04)
axs[1].set_xlim(1.e-3,1.e0)
# axs.legend(fontsize=16,bbox_to_anchor=(0.50,0.53))
# axs[1].set_title("Background comparison", fontsize=22)
axs[1].legend(fontsize=20,bbox_to_anchor=[0.5,0.82],ncol=3,loc="center",frameon=False)

# %% [markdown]
# ## Numerical check

# %%
kind = 'pow_zeta'
for redshift in redshifts:

#     k = data['gev'][kind]['z='+str(redshift)] [:,0]
#     file_gev = data['gev'][kind]['z='+str(redshift)] [:,1]
    # axs[1].loglog(file[:,2],file[:,3],"-",color =Colors[l], lw=3,label="gevolution")

    file_kev = data['kev'][kind]['z='+str(redshift)][:,1]
    axs[1].plot(k,np.abs(file_kev-file_gev)/file_gev,"-",color =Colors[l+1], lw=3,label="kevolution vs gevolution")

    file_kev_old = data['kev_old'][kind]['z='+str(redshift)][:,1]
    
#     print("At z:"+ str(redshifts[i]) + "\n kevolution vs gevolution max of relative error: " +  str(np.max(file_kev-file_gev )) + " \n kevolution_old vs gevolution max of relative error: " + np.max(file_kev_old-file_gev ) + " \n kevolution_old vs kevolution max of relative error: " + np.max(file_kev_old-file_kev ) )
    max_kev_gev = np.max(np.abs(file_kev-file_gev )/file_gev)
    max_kev_old_gev = np.max(np.abs(file_kev_old-file_gev )/file_gev)
    max_kev_old_kev = np.max(np.abs(file_kev_old-file_kev )/file_kev)

    print("At z:"+ str(redshift) + " \n kevolution_old vs kevolution max of relative error: " + str(max_kev_old_kev)  + " at k=" + str(k[where(np.abs(file_kev_old-file_kev )/file_kev == max_kev_old_kev)]))
# Out:
# At z:100
#  kevolution_old vs kevolution max of relative error: 0.0 at k=[0.00155833 0.00220381 0.00269911 ... 0.08458156 0.08461027 0.08548117]
# At z:50
#  kevolution_old vs kevolution max of relative error: 0.011338352971073934 at k=[0.00155833]
# At z:30
#  kevolution_old vs kevolution max of relative error: 0.003060297596472941 at k=[0.00155833]
# At z:20
#  kevolution_old vs kevolution max of relative error: 0.0005189451526136713 at k=[0.00155833]
# At z:10
#  kevolution_old vs kevolution max of relative error: 0.00051866487057591 at k=[0.00155833]
# At z:9
#  kevolution_old vs kevolution max of relative error: 0.0005531500540791248 at k=[0.00155833]
# At z:8
#  kevolution_old vs kevolution max of relative error: 0.0005780732662499326 at k=[0.00155833]
# At z:7
#  kevolution_old vs kevolution max of relative error: 0.0005951510668855918 at k=[0.00155833]
# At z:6
#  kevolution_old vs kevolution max of relative error: 0.0006009428859919786 at k=[0.00155833]
# At z:5
#  kevolution_old vs kevolution max of relative error: 0.0006017753104936086 at k=[0.00155833]
# At z:4
#  kevolution_old vs kevolution max of relative error: 0.0005980918740533765 at k=[0.00155833]
# At z:3
#  kevolution_old vs kevolution max of relative error: 0.0005874315081401061 at k=[0.00155833]
# At z:2.5
#  kevolution_old vs kevolution max of relative error: 0.000578755469844693 at k=[0.00155833]
# At z:2
#  kevolution_old vs kevolution max of relative error: 0.0005672023909682707 at k=[0.00155833]
# At z:1.5
#  kevolution_old vs kevolution max of relative error: 0.0005532314426423807 at k=[0.00155833]
# At z:1
#  kevolution_old vs kevolution max of relative error: 0.0005398824342656928 at k=[0.00155833]
# At z:0.9
#  kevolution_old vs kevolution max of relative error: 0.000537084060572019 at k=[0.00155833]
# At z:0.8
#  kevolution_old vs kevolution max of relative error: 0.00053601127460465 at k=[0.00155833]
# At z:0.7
#  kevolution_old vs kevolution max of relative error: 0.0005353865243366789 at k=[0.00155833]
# At z:0.6
#  kevolution_old vs kevolution max of relative error: 0.0005367888859412229 at k=[0.00155833]
# At z:0.5
#  kevolution_old vs kevolution max of relative error: 0.0005392503888314814 at k=[0.00155833]
# At z:0.4
#  kevolution_old vs kevolution max of relative error: 0.0005434731104419649 at k=[0.00155833]
# At z:0.3
#  kevolution_old vs kevolution max of relative error: 0.0005503180707420096 at k=[0.00155833]
# At z:0.2
#  kevolution_old vs kevolution max of relative error: 0.0005606637038155902 at k=[0.00155833]
# At z:0.1
#  kevolution_old vs kevolution max of relative error: 0.0005747040982764352 at k=[0.00155833]
# At z:0.05
#  kevolution_old vs kevolution max of relative error: 0.0005831386428235473 at k=[0.00155833]
# At z:0.01
#  kevolution_old vs kevolution max of relative error: 0.000591166088514825 at k=[0.00155833]
# At z:0
#  kevolution_old vs kevolution max of relative error: 7.314196856097144e-05 at k=[0.00155833]
