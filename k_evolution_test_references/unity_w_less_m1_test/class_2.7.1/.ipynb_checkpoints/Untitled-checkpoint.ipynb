# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d
from pylab import rcParams
import scipy.integrate as integrate
import h5py

ColorsI = ["red","blue","green","purple","darkcyan","gold","maroon","black","darkslategrey",
           "darkgreen","navy","indigo","magenta","salmon","dodgerblue","springgreen","plum",
           "cyan","khaki","lightcoral","gray"]
ColorsII = []
# NUM_COLORS = 20
cm = plt.get_cmap('gist_rainbow')
# plt.style.use('seaborn-paper')
plt.rcParams['font.serif'] = 'Ubuntu'
from matplotlib.colors import LogNorm

# %%
ppf = np.loadtxt('./ppf/class_kess_cs_e7_w_09_newt_ppf_z1_tk.dat')
noppf_kev = np.loadtxt('./class_kess_cs_e7_w_09_newt_z1_tk.dat')
noppf = np.loadtxt('./np_ppf//class_kess_cs_e7_w_09_newt_z1_tk.dat')

# %%
plt.figure(figsize=(16,10))
plt.loglog(ppf[:,0],-(ppf[:,4]),color="red")
plt.loglog(noppf[:,0],-(noppf[:,4]),color="blue")
plt.loglog(noppf_kev[:,0],-(noppf_kev[:,4]),color="green")

# plt.loglog(power_kess_gev_ppf[:,0],(power_kess_gev_ppf[:,1]),color="green")

# plt.ylim(1.e-10,1.e-5)

# %%
plt.figure(figsize=(16,10))
# plt.loglog(ppf[:,0],-(ppf[:,4]),color="red")
# plt.loglog(noppf[:,0],-(noppf[:,4]),color="blue")
plt.loglog(noppf_kev[:,0],-(noppf_kev[:,4]-noppf[:,4])/noppf[:,4],color="green")

# plt.loglog(power_kess_gev_ppf[:,0],(power_kess_gev_ppf[:,1]),color="green")

# plt.ylim(1.e-10,1.e-5)
